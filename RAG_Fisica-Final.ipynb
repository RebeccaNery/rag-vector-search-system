# %%
# Célula 1: Instalação de Bibliotecas
# !pip install google-generativeai qdrant-client python-dotenv pandas pypdf gradio
# Out:
# Requirement already satisfied: google-generativeai in c:\users\rebec\anaconda3\lib\site-packages (0.8.5)
# Requirement already satisfied: qdrant-client in c:\users\rebec\anaconda3\lib\site-packages (1.14.2)
# Requirement already satisfied: python-dotenv in c:\users\rebec\anaconda3\lib\site-packages (0.21.0)
# Requirement already satisfied: pandas in c:\users\rebec\anaconda3\lib\site-packages (2.2.2)
# Requirement already satisfied: pypdf in c:\users\rebec\anaconda3\lib\site-packages (5.5.0)
# Requirement already satisfied: gradio in c:\users\rebec\anaconda3\lib\site-packages (5.32.0)
# Requirement already satisfied: google-ai-generativelanguage==0.6.15 in c:\users\rebec\anaconda3\lib\site-packages (from google-generativeai) (0.6.15)
# Requirement already satisfied: google-api-core in c:\users\rebec\anaconda3\lib\site-packages (from google-generativeai) (2.24.2)
# Requirement already satisfied: google-api-python-client in c:\users\rebec\anaconda3\lib\site-packages (from google-generativeai) (2.170.0)
# Requirement already satisfied: google-auth>=2.15.0 in c:\users\rebec\anaconda3\lib\site-packages (from google-generativeai) (2.40.2)
# Requirement already satisfied: protobuf in c:\users\rebec\anaconda3\lib\site-packages (from google-generativeai) (5.29.5)
# Requirement already satisfied: pydantic in c:\users\rebec\anaconda3\lib\site-packages (from google-generativeai) (2.8.2)
# Requirement already satisfied: tqdm in c:\users\rebec\anaconda3\lib\site-packages (from google-generativeai) (4.66.5)
# Requirement already satisfied: typing-extensions in c:\users\rebec\anaconda3\lib\site-packages (from google-generativeai) (4.11.0)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in c:\users\rebec\anaconda3\lib\site-packages (from google-ai-generativelanguage==0.6.15->google-generativeai) (1.26.1)
# Requirement already satisfied: grpcio>=1.41.0 in c:\users\rebec\anaconda3\lib\site-packages (from qdrant-client) (1.71.0)
# Requirement already satisfied: httpx>=0.20.0 in c:\users\rebec\anaconda3\lib\site-packages (from httpx[http2]>=0.20.0->qdrant-client) (0.27.0)
# Requirement already satisfied: numpy>=1.26 in c:\users\rebec\anaconda3\lib\site-packages (from qdrant-client) (1.26.4)
# Requirement already satisfied: portalocker<3.0.0,>=2.7.0 in c:\users\rebec\anaconda3\lib\site-packages (from qdrant-client) (2.10.1)
# Requirement already satisfied: urllib3<3,>=1.26.14 in c:\users\rebec\anaconda3\lib\site-packages (from qdrant-client) (2.2.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\rebec\appdata\roaming\python\python312\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\rebec\anaconda3\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\rebec\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: aiofiles<25.0,>=22.0 in c:\users\rebec\anaconda3\lib\site-packages (from gradio) (24.1.0)
# Requirement already satisfied: anyio<5.0,>=3.0 in c:\users\rebec\anaconda3\lib\site-packages (from gradio) (4.2.0)
# Requirement already satisfied: fastapi<1.0,>=0.115.2 in c:\users\rebec\anaconda3\lib\site-packages (from gradio) (0.115.12)
# Requirement already satisfied: ffmpy in c:\users\rebec\anaconda3\lib\site-packages (from gradio) (0.5.0)
# Requirement already satisfied: gradio-client==1.10.2 in c:\users\rebec\anaconda3\lib\site-packages (from gradio) (1.10.2)
# Requirement already satisfied: groovy~=0.1 in c:\users\rebec\anaconda3\lib\site-packages (from gradio) (0.1.2)
# Requirement already satisfied: huggingface-hub>=0.28.1 in c:\users\rebec\anaconda3\lib\site-packages (from gradio) (0.32.3)
# Requirement already satisfied: jinja2<4.0 in c:\users\rebec\anaconda3\lib\site-packages (from gradio) (3.1.4)
# Requirement already satisfied: markupsafe<4.0,>=2.0 in c:\users\rebec\anaconda3\lib\site-packages (from gradio) (2.1.3)
# Requirement already satisfied: orjson~=3.0 in c:\users\rebec\anaconda3\lib\site-packages (from gradio) (3.10.18)
# Requirement already satisfied: packaging in c:\users\rebec\appdata\roaming\python\python312\site-packages (from gradio) (24.1)
# Requirement already satisfied: pillow<12.0,>=8.0 in c:\users\rebec\anaconda3\lib\site-packages (from gradio) (10.4.0)
# Requirement already satisfied: pydub in c:\users\rebec\anaconda3\lib\site-packages (from gradio) (0.25.1)
# Requirement already satisfied: python-multipart>=0.0.18 in c:\users\rebec\anaconda3\lib\site-packages (from gradio) (0.0.20)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in c:\users\rebec\anaconda3\lib\site-packages (from gradio) (6.0.1)
# Requirement already satisfied: ruff>=0.9.3 in c:\users\rebec\anaconda3\lib\site-packages (from gradio) (0.11.12)
# Requirement already satisfied: safehttpx<0.2.0,>=0.1.6 in c:\users\rebec\anaconda3\lib\site-packages (from gradio) (0.1.6)
# Requirement already satisfied: semantic-version~=2.0 in c:\users\rebec\anaconda3\lib\site-packages (from gradio) (2.10.0)
# Requirement already satisfied: starlette<1.0,>=0.40.0 in c:\users\rebec\anaconda3\lib\site-packages (from gradio) (0.46.2)
# Requirement already satisfied: tomlkit<0.14.0,>=0.12.0 in c:\users\rebec\anaconda3\lib\site-packages (from gradio) (0.13.2)
# Requirement already satisfied: typer<1.0,>=0.12 in c:\users\rebec\anaconda3\lib\site-packages (from gradio) (0.16.0)
# Requirement already satisfied: uvicorn>=0.14.0 in c:\users\rebec\anaconda3\lib\site-packages (from gradio) (0.34.2)
# Requirement already satisfied: fsspec in c:\users\rebec\anaconda3\lib\site-packages (from gradio-client==1.10.2->gradio) (2024.6.1)
# Requirement already satisfied: websockets<16.0,>=10.0 in c:\users\rebec\anaconda3\lib\site-packages (from gradio-client==1.10.2->gradio) (15.0.1)
# Requirement already satisfied: idna>=2.8 in c:\users\rebec\anaconda3\lib\site-packages (from anyio<5.0,>=3.0->gradio) (3.7)
# Requirement already satisfied: sniffio>=1.1 in c:\users\rebec\anaconda3\lib\site-packages (from anyio<5.0,>=3.0->gradio) (1.3.0)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in c:\users\rebec\anaconda3\lib\site-packages (from google-api-core->google-generativeai) (1.70.0)
# Requirement already satisfied: requests<3.0.0,>=2.18.0 in c:\users\rebec\anaconda3\lib\site-packages (from google-api-core->google-generativeai) (2.32.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\rebec\anaconda3\lib\site-packages (from google-auth>=2.15.0->google-generativeai) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\rebec\anaconda3\lib\site-packages (from google-auth>=2.15.0->google-generativeai) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\rebec\anaconda3\lib\site-packages (from google-auth>=2.15.0->google-generativeai) (4.9.1)
# Requirement already satisfied: certifi in c:\users\rebec\anaconda3\lib\site-packages (from httpx>=0.20.0->httpx[http2]>=0.20.0->qdrant-client) (2025.4.26)
# Requirement already satisfied: httpcore==1.* in c:\users\rebec\anaconda3\lib\site-packages (from httpx>=0.20.0->httpx[http2]>=0.20.0->qdrant-client) (1.0.2)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\rebec\anaconda3\lib\site-packages (from httpcore==1.*->httpx>=0.20.0->httpx[http2]>=0.20.0->qdrant-client) (0.14.0)
# Requirement already satisfied: h2<5,>=3 in c:\users\rebec\anaconda3\lib\site-packages (from httpx[http2]>=0.20.0->qdrant-client) (4.2.0)
# Requirement already satisfied: filelock in c:\users\rebec\anaconda3\lib\site-packages (from huggingface-hub>=0.28.1->gradio) (3.13.1)
# Requirement already satisfied: pywin32>=226 in c:\users\rebec\appdata\roaming\python\python312\site-packages (from portalocker<3.0.0,>=2.7.0->qdrant-client) (307)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\rebec\anaconda3\lib\site-packages (from pydantic->google-generativeai) (0.6.0)
# Requirement already satisfied: pydantic-core==2.20.1 in c:\users\rebec\anaconda3\lib\site-packages (from pydantic->google-generativeai) (2.20.1)
# Requirement already satisfied: six>=1.5 in c:\users\rebec\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: colorama in c:\users\rebec\appdata\roaming\python\python312\site-packages (from tqdm->google-generativeai) (0.4.6)
# Requirement already satisfied: click>=8.0.0 in c:\users\rebec\anaconda3\lib\site-packages (from typer<1.0,>=0.12->gradio) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\rebec\anaconda3\lib\site-packages (from typer<1.0,>=0.12->gradio) (1.5.0)
# Requirement already satisfied: rich>=10.11.0 in c:\users\rebec\anaconda3\lib\site-packages (from typer<1.0,>=0.12->gradio) (13.7.1)
# Requirement already satisfied: httplib2<1.0.0,>=0.19.0 in c:\users\rebec\anaconda3\lib\site-packages (from google-api-python-client->google-generativeai) (0.22.0)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in c:\users\rebec\anaconda3\lib\site-packages (from google-api-python-client->google-generativeai) (0.2.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in c:\users\rebec\anaconda3\lib\site-packages (from google-api-python-client->google-generativeai) (4.1.1)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in c:\users\rebec\anaconda3\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.15->google-generativeai) (1.71.0)
# Requirement already satisfied: hyperframe<7,>=6.1 in c:\users\rebec\anaconda3\lib\site-packages (from h2<5,>=3->httpx[http2]>=0.20.0->qdrant-client) (6.1.0)
# Requirement already satisfied: hpack<5,>=4.1 in c:\users\rebec\anaconda3\lib\site-packages (from h2<5,>=3->httpx[http2]>=0.20.0->qdrant-client) (4.1.0)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in c:\users\rebec\anaconda3\lib\site-packages (from httplib2<1.0.0,>=0.19.0->google-api-python-client->google-generativeai) (3.1.2)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\rebec\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth>=2.15.0->google-generativeai) (0.4.8)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\rebec\anaconda3\lib\site-packages (from requests<3.0.0,>=2.18.0->google-api-core->google-generativeai) (3.3.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\rebec\anaconda3\lib\site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\rebec\appdata\roaming\python\python312\site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\rebec\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0,>=0.12->gradio) (0.1.0)

# %%
#CÉLULA 2 - Importações e configuração do Gemini e do Qdrant
import os
import time
import pandas as pd # Para carregar dados de exemplo, opcional
from dotenv import load_dotenv
import google.generativeai as genai
from qdrant_client import QdrantClient, models

# Carregar variáveis de ambiente do arquivo .env
load_dotenv()

# Configurar a API do Google AI (Gemini)
GOOGLE_AI_API_KEY = os.getenv("GOOGLE_AI_API_KEY")
if not GOOGLE_AI_API_KEY:
    print("AVISO: GOOGLE_AI_API_KEY não encontrada. Verifique seu arquivo .env ou defina a variável.")
else:
    genai.configure(api_key=GOOGLE_AI_API_KEY)
    print("SDK do Google AI (Gemini) configurado com sucesso.")

# Configurar o cliente Qdrant
QDRANT_URL = os.getenv("QDRANT_URL")
QDRANT_API_KEY = os.getenv("QDRANT_API_KEY")

qdrant_client = None # Inicializa como None

if QDRANT_URL and "cloud.qdrant.io" in QDRANT_URL: # Verifica se parece uma URL de nuvem
    print(f"Tentando conectar ao Qdrant Cloud em: {QDRANT_URL}")
    if not QDRANT_API_KEY:
        print("AVISO: QDRANT_API_KEY não encontrada para Qdrant Cloud. A conexão pode falhar.")
    try:
        qdrant_client = QdrantClient(url=QDRANT_URL, api_key=QDRANT_API_KEY, timeout=60) # Timeout aumentado
        qdrant_client.get_collections() # Testa a conexão
        print("Conectado ao Qdrant Cloud com sucesso!")
    except Exception as e:
        print(f"ERRO ao conectar ao Qdrant Cloud: {e}")
        print("Fallback para Qdrant rodando localmente ou em memória.")
        qdrant_client = None # Garante que não usaremos uma instância falha

if not qdrant_client: # Se não conectou à nuvem ou não havia URL da nuvem
    try:
        # Tenta conectar a uma instância local do Qdrant
        qdrant_client = QdrantClient(host="localhost", port=6333)
        qdrant_client.get_collections() # Testa a conexão
        print("Conectado ao Qdrant local (localhost:6333) com sucesso!")
    except Exception as e_local:
        print(f"ERRO ao conectar ao Qdrant local: {e_local}")
        qdrant_client = QdrantClient(":memory:")
        print("ATENÇÃO: Qdrant rodando em memória. Os dados serão perdidos ao fechar.")

print("\n--- Configurações de clientes concluídas. ---")
# Out:
# SDK do Google AI (Gemini) configurado com sucesso.
# Tentando conectar ao Qdrant Cloud em: https://1346b74e-7bf3-489a-b4cc-b1eacb715c46.europe-west3-0.gcp.cloud.qdrant.io
# Conectado ao Qdrant Cloud com sucesso!
#
# --- Configurações de clientes concluídas. ---

# %%
# CÉLULA 3 - Criação da coleção no qdrant

# Definições para a coleção e embeddings
COLLECTION_NAME = "fisica_ensino_medio_chunks" # Nome da coleção
GEMINI_EMBEDDING_MODEL = 'models/embedding-001' # Modelo de embedding do Gemini
GEMINI_EMBEDDING_DIMENSION = 768  # Dimensão dos embeddings para 'models/embedding-001'
MODELO_GEMINI_PARA_GERACAO = "gemini-1.5-flash-latest" # Ou "gemini-1.0-pro-latest", etc.

if qdrant_client: # Assume que qdrant_client foi inicializado na Célula 2
    try:
        collection_info = qdrant_client.get_collection(collection_name=COLLECTION_NAME)
        print(f"Coleção '{COLLECTION_NAME}' já existe.")
        
        current_dimension = None
        vectors_config = collection_info.config.params.vectors

        # Para coleções criadas com models.VectorParams (vetor único padrão), 
        # vectors_config será uma instância de models.VectorParams.
        if isinstance(vectors_config, models.VectorParams):
            current_dimension = vectors_config.size
        elif isinstance(vectors_config, dict) and models.DEFAULT_VECTOR_NAME in vectors_config:
             # Caso de vetores nomeados, pegamos o default se existir
            current_dimension = vectors_config[models.DEFAULT_VECTOR_NAME].size
        else:
            print(f"AVISO: Não foi possível determinar a configuração de vetores da coleção '{COLLECTION_NAME}' da forma esperada.")
            # Você pode adicionar mais lógica aqui se usar configurações de vetores mais complexas.

        if current_dimension is not None: # Prossegue apenas se a dimensão foi encontrada
            if current_dimension != GEMINI_EMBEDDING_DIMENSION:
                print(f"ALERTA: Dimensão da coleção existente ({current_dimension}) é DIFERENTE da esperada ({GEMINI_EMBEDDING_DIMENSION}).")
                print("Isso CAUSARÁ ERROS ao tentar inserir ou buscar vetores com a dimensão incorreta.")
                print(f"Soluções: Use outra coleção, apague e recrie esta coleção '{COLLECTION_NAME}', ou ajuste GEMINI_EMBEDDING_DIMENSION se o modelo mudou.")
                # Exemplo para apagar (CUIDADO: APAGA TODOS OS DADOS DA COLEÇÃO):
                # print(f"Para apagar e recriar, descomente e execute: qdrant_client.delete_collection(collection_name=COLLECTION_NAME)")
                # raise Exception("Dimensão da coleção incompatível. Interrompendo para evitar mais erros.")
            else:
                print(f"Dimensão da coleção existente ({current_dimension}) é compatível com a dimensão esperada ({GEMINI_EMBEDDING_DIMENSION}).")
        elif collection_info: # Se current_dimension não foi setada mas a coleção existe
             print(f"Não foi possível verificar a dimensão da coleção '{COLLECTION_NAME}'. Prossiga com cautela.")


    except Exception as e:
        # Trata erros como "não encontrado" de forma mais genérica
        # Também inclui o caso de ValueError que pode vir de um `raise Exception` acima se descomentado.
        if "not found" in str(e).lower() or "status_code=404" in str(e).lower() or "status code 404" in str(e).lower() or isinstance(e, ValueError):
            print(f"Coleção '{COLLECTION_NAME}' não encontrada ou marcada para recriação. Criando nova coleção...")
            try:
                qdrant_client.create_collection(
                    collection_name=COLLECTION_NAME,
                    vectors_config=models.VectorParams(
                        size=GEMINI_EMBEDDING_DIMENSION,
                        distance=models.Distance.COSINE
                    )
                )
                print(f"Coleção '{COLLECTION_NAME}' criada com sucesso com dimensão {GEMINI_EMBEDDING_DIMENSION}.")
            except Exception as e_create:
                print(f"ERRO CRÍTICO ao criar a coleção '{COLLECTION_NAME}': {e_create}")
        else:
            print(f"Erro desconhecido ao verificar/criar coleção '{COLLECTION_NAME}': {e}")
            import traceback
            traceback.print_exc()
else:
    print("ERRO CRÍTICO: Cliente Qdrant não inicializado na Célula 2. Não é possível configurar a coleção.")

print("\n--- Configuração da coleção Qdrant concluída. ---")
# Out:
# Coleção 'fisica_ensino_medio_chunks' já existe.
# Dimensão da coleção existente (768) é compatível com a dimensão esperada (768).
#
# --- Configuração da coleção Qdrant concluída. ---

# %%
# CÉLULA 4 - Definição da função gerar_e_armazenar_embeddings
import uuid # Para IDs únicos, se necessário

def gerar_e_armazenar_embeddings_gemini(text_chunks_dicts, collection_name, q_client, gemini_model,
                                        qdrant_upsert_batch_size=100, gemini_api_call_batch_size=30):
    """
    Gera embeddings para uma lista de chunks (dicionários) usando Gemini e os armazena no Qdrant.
    Cada chunk é um dicionário esperado com, no mínimo, a chave "texto_original".
    """
    if not GOOGLE_AI_API_KEY:
        print("ERRO: Chave da API do Google AI não configurada. Abortando.")
        return
    if not q_client:
        print("ERRO: Cliente Qdrant não configurado. Abortando.")
        return
    if not text_chunks_dicts:
        print("AVISO: Lista de text_chunks_dicts está vazia. Nada para processar.")
        return

    pontos_para_upsert = []
    total_chunks_count = len(text_chunks_dicts)
    chunks_processados_global = 0
    
    # Usaremos um contador global para IDs sequenciais simples nesta execução.
    # Para robustez entre múltiplas execuções ou atualizações incrementais, UUIDs são melhores.
    id_counter = 0 

    print(f"Iniciando geração e armazenamento de embeddings com Gemini para {total_chunks_count} chunks...")
    start_time_total_process = time.time()
    last_log_time = time.time()
    log_interval_seconds = 10

    for i in range(0, total_chunks_count, gemini_api_call_batch_size):
        current_batch_chunk_dicts = text_chunks_dicts[i:i + gemini_api_call_batch_size]
        if not current_batch_chunk_dicts:
            continue

        texts_for_embedding_api = []
        valid_dicts_in_batch = [] # Para manter correspondência com os embeddings retornados
        for chunk_dict in current_batch_chunk_dicts:
            if isinstance(chunk_dict, dict) and "texto_original" in chunk_dict and chunk_dict["texto_original"].strip():
                texts_for_embedding_api.append(chunk_dict["texto_original"])
                valid_dicts_in_batch.append(chunk_dict)
            else:
                print(f"  AVISO: Chunk inválido ou sem texto_original encontrado no lote (índice original ~{i+len(valid_dicts_in_batch)}), será pulado para embedding.")
        
        if not texts_for_embedding_api:
            print(f"  AVISO: Nenhum texto válido para embedding no lote iniciando em {i}. Pulando lote da API Gemini.")
            chunks_processados_global += len(current_batch_chunk_dicts) # Conta como processados para o loop principal
            continue
            
        print(f"\nProcessando lote de {len(texts_for_embedding_api)} textos válidos para API Gemini (de {len(current_batch_chunk_dicts)} chunks originais no lote)...")
        
        try:
            result = genai.embed_content(
                model=gemini_model,
                content=texts_for_embedding_api,
                task_type="RETRIEVAL_DOCUMENT"
            )
            batch_embeddings_vectors = result['embedding']

            if len(batch_embeddings_vectors) != len(texts_for_embedding_api):
                print(f"  ALERTA: Discrepância no lote Gemini. Textos enviados: {len(texts_for_embedding_api)}, Embeddings recebidos: {len(batch_embeddings_vectors)}. Pulando este lote da API.")
                chunks_processados_global += len(current_batch_chunk_dicts)
                continue

            for original_chunk_dict, vector_embedding in zip(valid_dicts_in_batch, batch_embeddings_vectors):
                payload_content = original_chunk_dict.copy()
                
                # Geração de ID:
                # Se você limpar a coleção a cada vez, um contador simples pode funcionar.
                # Se for adicionar incrementalmente, use UUIDs ou um hash do conteúdo + origem.
                # current_id = str(uuid.uuid4()) # Opção UUID
                current_id = id_counter # Opção sequencial simples para esta execução
                id_counter += 1

                pontos_para_upsert.append(
                    models.PointStruct(
                        id=current_id,
                        vector=vector_embedding,
                        payload=payload_content
                    )
                )
            
            print(f"  Lote da API Gemini processado. {len(batch_embeddings_vectors)} embeddings gerados.")

        except Exception as e:
            print(f"  ERRO CRÍTICO ao processar lote da API Gemini (iniciando em chunk {i}): {e}")
            print(f"  Este lote será pulado. Tentando continuar com o próximo lote...")
            import traceback
            traceback.print_exc()
            time.sleep(5) # Pausa maior em caso de erro de API
            # Importante: incrementar chunks_processados_global mesmo em erro para o loop avançar
            # ou ter uma lógica de retentativa mais sofisticada.
            # Por simplicidade, aqui estamos pulando o lote inteiro em caso de erro na API.
        
        chunks_processados_global += len(current_batch_chunk_dicts) # Atualiza com base no lote original processado/tentado

        # Upsert no Qdrant
        if len(pontos_para_upsert) >= qdrant_upsert_batch_size or \
           (chunks_processados_global >= total_chunks_count and len(pontos_para_upsert) > 0): # >= para o caso de pularmos lotes
            if pontos_para_upsert: # Apenas se houver pontos para enviar
                print(f"  Enviando {len(pontos_para_upsert)} pontos para Qdrant...")
                try:
                    q_client.upsert(
                        collection_name=collection_name,
                        points=pontos_para_upsert,
                        wait=True
                    )
                    print(f"  {len(pontos_para_upsert)} pontos enviados ao Qdrant.")
                except Exception as e_qdrant:
                    print(f"  ERRO CRÍTICO ao enviar pontos para o Qdrant: {e_qdrant}")
                    traceback.print_exc()
                finally:
                    pontos_para_upsert = [] # Limpa mesmo em erro para não reenviar os mesmos pontos
        
        # Delay entre chamadas à API Gemini
        if i + gemini_api_call_batch_size < total_chunks_count: # Evita sleep após o último lote
             print(f"  Aguardando para a próxima chamada à API Gemini...")
             time.sleep(1.1) # Pausa para respeitar limites de RPM (60 RPM para embedding-001 free tier)


        current_time = time.time()
        if current_time - last_log_time > log_interval_seconds or chunks_processados_global >= total_chunks_count:
            progress_percent = (chunks_processados_global / total_chunks_count) * 100 if total_chunks_count > 0 else 0
            elapsed_total = current_time - start_time_total_process
            print(f"\nProgresso Atual: {progress_percent:.2f}% ({chunks_processados_global}/{total_chunks_count} chunks avaliados). Tempo total: {elapsed_total:.2f}s")
            last_log_time = current_time

    # Garantir que qualquer ponto restante seja enviado
    if len(pontos_para_upsert) > 0 and q_client:
        print(f"\nEnviando lote final de {len(pontos_para_upsert)} pontos para Qdrant...")
        try:
            q_client.upsert(
                collection_name=collection_name,
                points=pontos_para_upsert,
                wait=True
            )
            print(f"  {len(pontos_para_upsert)} pontos finais enviados ao Qdrant.")
        except Exception as e_qdrant_final:
            print(f"  ERRO CRÍTICO ao enviar lote final para o Qdrant: {e_qdrant_final}")
            import traceback
            traceback.print_exc()
        finally:
            pontos_para_upsert = []


    print(f"\n--- Geração e armazenamento de embeddings com Gemini CONCLUÍDOS! Total de {chunks_processados_global} chunks avaliados. ---")

# %%
# CÉLULA 5 - Leitura dos PDFs + divisão em chunks
# Esta célula é, portanto, a etapa de PRÉ-PROCESSAMENTO de dados que alimenta o 
# restante do pipeline de IA do notebook. Ela transforma o conteúdo bruto dos PDFs 
# em um formato ESTRUTURADO (lista de dicionários de chunks) pronto para a vetorização.
from pypdf import PdfReader 
import os # Para pegar o nome do arquivo

def extrair_texto_pdf(caminho_pdf):
    """Extrai texto de um arquivo PDF, uma string por página, incluindo o nome do arquivo no log."""
    textos_das_paginas = []
    nome_arquivo = os.path.basename(caminho_pdf) # Pega apenas o nome do arquivo do caminho
    try:
        leitor = PdfReader(caminho_pdf)
        num_paginas = len(leitor.pages)
        print(f"Lendo PDF: '{nome_arquivo}' com {num_paginas} páginas.")
        for i, pagina in enumerate(leitor.pages):
            texto_pagina = pagina.extract_text()
            if texto_pagina:
                # Adiciona metadados da página ao texto do chunk (ainda como string temporariamente)
                textos_das_paginas.append({"texto_bruto": texto_pagina.strip(), "pagina_num": i + 1, "arquivo_origem": nome_arquivo})
            else:
                print(f"  Aviso: Não foi possível extrair texto da página {i+1} do arquivo '{nome_arquivo}'.")
        print(f"Texto extraído de {len(textos_das_paginas)} páginas do arquivo '{nome_arquivo}'.")
    except FileNotFoundError:
        print(f"ERRO: Arquivo PDF não encontrado em '{caminho_pdf}'.")
        return []
    except Exception as e:
        print(f"ERRO ao ler o PDF '{caminho_pdf}': {e}")
        return []
    return textos_das_paginas

def dividir_texto_em_chunks_com_metadata(textos_com_metadata_pagina, max_chars_por_chunk=2000, overlap_chars=200):
    """Divide textos (que já são dicionários com metadados de página) em chunks menores."""
    chunks_finais_formatados = []
    for item_pagina in textos_com_metadata_pagina:
        texto_original_pagina = item_pagina["texto_bruto"]
        pagina_num = item_pagina["pagina_num"]
        arquivo_origem = item_pagina["arquivo_origem"]

        if len(texto_original_pagina) <= max_chars_por_chunk:
            chunks_finais_formatados.append({
                "texto_original": texto_original_pagina,
                "pagina": pagina_num,
                "arquivo_origem": arquivo_origem
            })
            continue
        
        print(f"Dividindo texto da página {pagina_num} do arquivo '{arquivo_origem}' (aprox {len(texto_original_pagina)} caracteres)...")
        
        inicio = 0
        while inicio < len(texto_original_pagina):
            fim = min(inicio + max_chars_por_chunk, len(texto_original_pagina))
            chunk_texto = texto_original_pagina[inicio:fim]
            
            chunks_finais_formatados.append({
                "texto_original": chunk_texto,
                "pagina": pagina_num, # A página original de onde este chunk veio
                "arquivo_origem": arquivo_origem
            })
            
            if fim == len(texto_original_pagina):
                break 
            
            inicio += (max_chars_por_chunk - overlap_chars)
            if inicio >= len(texto_original_pagina):
                 break
    # print(f"Total de chunks após divisão para este PDF: {len(chunks_finais_formatados)}") # Removido para log global
    return chunks_finais_formatados


# Lista dos caminhos para os os arquivos PDF
LISTA_CAMINHOS_PDFS = [
    r"G:\Meu Drive\Acadêmico\CC - Unipê\P6 - 2025.1\Fundamentos_IA\Trabalho_AV2_RAG\Apostila-Física.pdf",
    r"G:\Meu Drive\Acadêmico\CC - Unipê\P6 - 2025.1\Fundamentos_IA\Trabalho_AV2_RAG\fisica2.pdf",
    r"G:\Meu Drive\Acadêmico\CC - Unipê\P6 - 2025.1\Fundamentos_IA\Trabalho_AV2_RAG\fisica3.pdf" ]

todos_os_chunks_formatados = [] # Lista global para todos os chunks de todos os PDFs

for caminho_pdf_atual in LISTA_CAMINHOS_PDFS:
    print(f"\n--- Processando arquivo: {os.path.basename(caminho_pdf_atual)} ---")
    # Extrai o texto bruto, já como lista de dicionários por página
    textos_por_pagina_com_meta = extrair_texto_pdf(caminho_pdf_atual)

    if textos_por_pagina_com_meta:
        # Divide os textos das páginas em chunks menores, mantendo/adicionando metadados
        chunks_do_pdf_atual = dividir_texto_em_chunks_com_metadata(
            textos_por_pagina_com_meta,
            max_chars_por_chunk=2000,
            overlap_chars=200
        )
        todos_os_chunks_formatados.extend(chunks_do_pdf_atual)
        print(f"Adicionados {len(chunks_do_pdf_atual)} chunks do arquivo '{os.path.basename(caminho_pdf_atual)}'.")

# A variável final que será usada nas próximas células
chunks_de_texto = todos_os_chunks_formatados

if chunks_de_texto:
    print(f"\nTotal de {len(chunks_de_texto)} chunks de texto preparados de {len(LISTA_CAMINHOS_PDFS)} arquivo(s) PDF.")
    print("\nExemplo do primeiro chunk formatado:")
    if isinstance(chunks_de_texto[0], dict):
        for chave, valor in chunks_de_texto[0].items():
            print(f"  {chave}: {str(valor)[:200]}...") 
    else:
        print(str(chunks_de_texto[0])[:500] + "...")
else:
    print("\nAVISO: Nenhum chunk de texto foi preparado. Verifique os caminhos dos PDFs e a extração.")

print("\n--- Preparação dos dados de múltiplos PDFs concluída. ---")
# Out:
# --- Processando arquivo: Apostila-Física.pdf ---
# Lendo PDF: 'Apostila-Física.pdf' com 48 páginas.
# Texto extraído de 48 páginas do arquivo 'Apostila-Física.pdf'.
# Dividindo texto da página 2 do arquivo 'Apostila-Física.pdf' (aprox 3319 caracteres)...
# Dividindo texto da página 3 do arquivo 'Apostila-Física.pdf' (aprox 3794 caracteres)...
# Dividindo texto da página 4 do arquivo 'Apostila-Física.pdf' (aprox 2649 caracteres)...
# Dividindo texto da página 6 do arquivo 'Apostila-Física.pdf' (aprox 2463 caracteres)...
# Dividindo texto da página 7 do arquivo 'Apostila-Física.pdf' (aprox 2156 caracteres)...
# Dividindo texto da página 10 do arquivo 'Apostila-Física.pdf' (aprox 2283 caracteres)...
# Dividindo texto da página 15 do arquivo 'Apostila-Física.pdf' (aprox 2581 caracteres)...
# Dividindo texto da página 16 do arquivo 'Apostila-Física.pdf' (aprox 2660 caracteres)...
# Dividindo texto da página 18 do arquivo 'Apostila-Física.pdf' (aprox 2212 caracteres)...
# Dividindo texto da página 19 do arquivo 'Apostila-Física.pdf' (aprox 2252 caracteres)...
# Dividindo texto da página 21 do arquivo 'Apostila-Física.pdf' (aprox 2635 caracteres)...
# Dividindo texto da página 23 do arquivo 'Apostila-Física.pdf' (aprox 2130 caracteres)...
# Dividindo texto da página 24 do arquivo 'Apostila-Física.pdf' (aprox 2837 caracteres)...
# Dividindo texto da página 25 do arquivo 'Apostila-Física.pdf' (aprox 2068 caracteres)...
# Dividindo texto da página 26 do arquivo 'Apostila-Física.pdf' (aprox 2363 caracteres)...
# Dividindo texto da página 28 do arquivo 'Apostila-Física.pdf' (aprox 2093 caracteres)...
# Dividindo texto da página 29 do arquivo 'Apostila-Física.pdf' (aprox 2275 caracteres)...
# Dividindo texto da página 32 do arquivo 'Apostila-Física.pdf' (aprox 2793 caracteres)...
# Dividindo texto da página 33 do arquivo 'Apostila-Física.pdf' (aprox 2061 caracteres)...
# Dividindo texto da página 35 do arquivo 'Apostila-Física.pdf' (aprox 2329 caracteres)...
# Dividindo texto da página 36 do arquivo 'Apostila-Física.pdf' (aprox 2741 caracteres)...
# Dividindo texto da página 44 do arquivo 'Apostila-Física.pdf' (aprox 2171 caracteres)...
# Adicionados 70 chunks do arquivo 'Apostila-Física.pdf'.
#
# --- Processando arquivo: fisica2.pdf ---
# Lendo PDF: 'fisica2.pdf' com 216 páginas.
# Texto extraído de 216 páginas do arquivo 'fisica2.pdf'.
# Dividindo texto da página 1 do arquivo 'fisica2.pdf' (aprox 2589 caracteres)...
# Dividindo texto da página 2 do arquivo 'fisica2.pdf' (aprox 3675 caracteres)...
# Dividindo texto da página 3 do arquivo 'fisica2.pdf' (aprox 4671 caracteres)...
# Dividindo texto da página 4 do arquivo 'fisica2.pdf' (aprox 5384 caracteres)...
# Dividindo texto da página 5 do arquivo 'fisica2.pdf' (aprox 14915 caracteres)...
# Dividindo texto da página 6 do arquivo 'fisica2.pdf' (aprox 3174 caracteres)...
# Dividindo texto da página 7 do arquivo 'fisica2.pdf' (aprox 2322 caracteres)...
# Dividindo texto da página 8 do arquivo 'fisica2.pdf' (aprox 3699 caracteres)...
# Dividindo texto da página 9 do arquivo 'fisica2.pdf' (aprox 3112 caracteres)...
# Dividindo texto da página 10 do arquivo 'fisica2.pdf' (aprox 3296 caracteres)...
# Dividindo texto da página 11 do arquivo 'fisica2.pdf' (aprox 3232 caracteres)...
# Dividindo texto da página 12 do arquivo 'fisica2.pdf' (aprox 3976 caracteres)...
# Dividindo texto da página 14 do arquivo 'fisica2.pdf' (aprox 2465 caracteres)...
# Dividindo texto da página 15 do arquivo 'fisica2.pdf' (aprox 2472 caracteres)...
# Dividindo texto da página 16 do arquivo 'fisica2.pdf' (aprox 5684 caracteres)...
# Dividindo texto da página 17 do arquivo 'fisica2.pdf' (aprox 3592 caracteres)...
# Dividindo texto da página 18 do arquivo 'fisica2.pdf' (aprox 3575 caracteres)...
# Dividindo texto da página 19 do arquivo 'fisica2.pdf' (aprox 6398 caracteres)...
# Dividindo texto da página 20 do arquivo 'fisica2.pdf' (aprox 4592 caracteres)...
# Dividindo texto da página 21 do arquivo 'fisica2.pdf' (aprox 5046 caracteres)...
# Dividindo texto da página 23 do arquivo 'fisica2.pdf' (aprox 3212 caracteres)...
# Dividindo texto da página 24 do arquivo 'fisica2.pdf' (aprox 5042 caracteres)...
# Dividindo texto da página 25 do arquivo 'fisica2.pdf' (aprox 3315 caracteres)...
# Dividindo texto da página 26 do arquivo 'fisica2.pdf' (aprox 3508 caracteres)...
# Dividindo texto da página 27 do arquivo 'fisica2.pdf' (aprox 2615 caracteres)...
# Dividindo texto da página 28 do arquivo 'fisica2.pdf' (aprox 3183 caracteres)...
# Dividindo texto da página 29 do arquivo 'fisica2.pdf' (aprox 3846 caracteres)...
# Dividindo texto da página 30 do arquivo 'fisica2.pdf' (aprox 2495 caracteres)...
# Dividindo texto da página 31 do arquivo 'fisica2.pdf' (aprox 3872 caracteres)...
# Dividindo texto da página 32 do arquivo 'fisica2.pdf' (aprox 4838 caracteres)...
# Dividindo texto da página 33 do arquivo 'fisica2.pdf' (aprox 2165 caracteres)...
# Dividindo texto da página 34 do arquivo 'fisica2.pdf' (aprox 2862 caracteres)...
# Dividindo texto da página 35 do arquivo 'fisica2.pdf' (aprox 4875 caracteres)...
# Dividindo texto da página 36 do arquivo 'fisica2.pdf' (aprox 2855 caracteres)...
# Dividindo texto da página 37 do arquivo 'fisica2.pdf' (aprox 6161 caracteres)...
# Dividindo texto da página 38 do arquivo 'fisica2.pdf' (aprox 5407 caracteres)...
# Dividindo texto da página 39 do arquivo 'fisica2.pdf' (aprox 3626 caracteres)...
# Dividindo texto da página 40 do arquivo 'fisica2.pdf' (aprox 5676 caracteres)...
# Dividindo texto da página 42 do arquivo 'fisica2.pdf' (aprox 2782 caracteres)...
# Dividindo texto da página 43 do arquivo 'fisica2.pdf' (aprox 2585 caracteres)...
# Dividindo texto da página 44 do arquivo 'fisica2.pdf' (aprox 2912 caracteres)...
# Dividindo texto da página 45 do arquivo 'fisica2.pdf' (aprox 4906 caracteres)...
# Dividindo texto da página 47 do arquivo 'fisica2.pdf' (aprox 2997 caracteres)...
# Dividindo texto da página 48 do arquivo 'fisica2.pdf' (aprox 3510 caracteres)...
# Dividindo texto da página 49 do arquivo 'fisica2.pdf' (aprox 4885 caracteres)...
# Dividindo texto da página 50 do arquivo 'fisica2.pdf' (aprox 2386 caracteres)...
# Dividindo texto da página 51 do arquivo 'fisica2.pdf' (aprox 3789 caracteres)...
# Dividindo texto da página 52 do arquivo 'fisica2.pdf' (aprox 2089 caracteres)...
# Dividindo texto da página 53 do arquivo 'fisica2.pdf' (aprox 5105 caracteres)...
# Dividindo texto da página 54 do arquivo 'fisica2.pdf' (aprox 2669 caracteres)...
# Dividindo texto da página 55 do arquivo 'fisica2.pdf' (aprox 2039 caracteres)...
# Dividindo texto da página 56 do arquivo 'fisica2.pdf' (aprox 3555 caracteres)...
# Dividindo texto da página 57 do arquivo 'fisica2.pdf' (aprox 5763 caracteres)...
# Dividindo texto da página 58 do arquivo 'fisica2.pdf' (aprox 5619 caracteres)...
# Dividindo texto da página 59 do arquivo 'fisica2.pdf' (aprox 5116 caracteres)...
# Dividindo texto da página 60 do arquivo 'fisica2.pdf' (aprox 6082 caracteres)...
# Dividindo texto da página 61 do arquivo 'fisica2.pdf' (aprox 5043 caracteres)...
# Dividindo texto da página 62 do arquivo 'fisica2.pdf' (aprox 5957 caracteres)...
# Dividindo texto da página 65 do arquivo 'fisica2.pdf' (aprox 2625 caracteres)...
# Dividindo texto da página 66 do arquivo 'fisica2.pdf' (aprox 3114 caracteres)...
# Dividindo texto da página 67 do arquivo 'fisica2.pdf' (aprox 4443 caracteres)...
# Dividindo texto da página 68 do arquivo 'fisica2.pdf' (aprox 4055 caracteres)...
# Dividindo texto da página 69 do arquivo 'fisica2.pdf' (aprox 2952 caracteres)...
# Dividindo texto da página 70 do arquivo 'fisica2.pdf' (aprox 4645 caracteres)...
# Dividindo texto da página 71 do arquivo 'fisica2.pdf' (aprox 3036 caracteres)...
# Dividindo texto da página 72 do arquivo 'fisica2.pdf' (aprox 3401 caracteres)...
# Dividindo texto da página 73 do arquivo 'fisica2.pdf' (aprox 4025 caracteres)...
# Dividindo texto da página 74 do arquivo 'fisica2.pdf' (aprox 4505 caracteres)...
# Dividindo texto da página 75 do arquivo 'fisica2.pdf' (aprox 6509 caracteres)...
# Dividindo texto da página 76 do arquivo 'fisica2.pdf' (aprox 4854 caracteres)...
# Dividindo texto da página 77 do arquivo 'fisica2.pdf' (aprox 5023 caracteres)...
# Dividindo texto da página 78 do arquivo 'fisica2.pdf' (aprox 3446 caracteres)...
# Dividindo texto da página 79 do arquivo 'fisica2.pdf' (aprox 4341 caracteres)...
# Dividindo texto da página 80 do arquivo 'fisica2.pdf' (aprox 4762 caracteres)...
# Dividindo texto da página 81 do arquivo 'fisica2.pdf' (aprox 4957 caracteres)...
# Dividindo texto da página 82 do arquivo 'fisica2.pdf' (aprox 5713 caracteres)...
# Dividindo texto da página 84 do arquivo 'fisica2.pdf' (aprox 2195 caracteres)...
# Dividindo texto da página 85 do arquivo 'fisica2.pdf' (aprox 5023 caracteres)...
# Dividindo texto da página 86 do arquivo 'fisica2.pdf' (aprox 3316 caracteres)...
# Dividindo texto da página 87 do arquivo 'fisica2.pdf' (aprox 2805 caracteres)...
# Dividindo texto da página 88 do arquivo 'fisica2.pdf' (aprox 3414 caracteres)...
# Dividindo texto da página 89 do arquivo 'fisica2.pdf' (aprox 2426 caracteres)...
# Dividindo texto da página 90 do arquivo 'fisica2.pdf' (aprox 4290 caracteres)...
# Dividindo texto da página 91 do arquivo 'fisica2.pdf' (aprox 2604 caracteres)...
# Dividindo texto da página 92 do arquivo 'fisica2.pdf' (aprox 5849 caracteres)...
# Dividindo texto da página 93 do arquivo 'fisica2.pdf' (aprox 3920 caracteres)...
# Dividindo texto da página 94 do arquivo 'fisica2.pdf' (aprox 3011 caracteres)...
# Dividindo texto da página 95 do arquivo 'fisica2.pdf' (aprox 5694 caracteres)...
# Dividindo texto da página 96 do arquivo 'fisica2.pdf' (aprox 6412 caracteres)...
# Dividindo texto da página 97 do arquivo 'fisica2.pdf' (aprox 5834 caracteres)...
# Dividindo texto da página 98 do arquivo 'fisica2.pdf' (aprox 6028 caracteres)...
# Dividindo texto da página 99 do arquivo 'fisica2.pdf' (aprox 2323 caracteres)...
# Dividindo texto da página 100 do arquivo 'fisica2.pdf' (aprox 4454 caracteres)...
# Dividindo texto da página 101 do arquivo 'fisica2.pdf' (aprox 4297 caracteres)...
# Dividindo texto da página 102 do arquivo 'fisica2.pdf' (aprox 3116 caracteres)...
# Dividindo texto da página 103 do arquivo 'fisica2.pdf' (aprox 4794 caracteres)...
# Dividindo texto da página 104 do arquivo 'fisica2.pdf' (aprox 3020 caracteres)...
# Dividindo texto da página 105 do arquivo 'fisica2.pdf' (aprox 3427 caracteres)...
# Dividindo texto da página 106 do arquivo 'fisica2.pdf' (aprox 3395 caracteres)...
# Dividindo texto da página 107 do arquivo 'fisica2.pdf' (aprox 2745 caracteres)...
# Dividindo texto da página 109 do arquivo 'fisica2.pdf' (aprox 5186 caracteres)...
# Dividindo texto da página 110 do arquivo 'fisica2.pdf' (aprox 2602 caracteres)...
# Dividindo texto da página 111 do arquivo 'fisica2.pdf' (aprox 2573 caracteres)...
# Dividindo texto da página 112 do arquivo 'fisica2.pdf' (aprox 3936 caracteres)...
# Dividindo texto da página 113 do arquivo 'fisica2.pdf' (aprox 4068 caracteres)...
# Dividindo texto da página 114 do arquivo 'fisica2.pdf' (aprox 4478 caracteres)...
# Dividindo texto da página 115 do arquivo 'fisica2.pdf' (aprox 2112 caracteres)...
# Dividindo texto da página 116 do arquivo 'fisica2.pdf' (aprox 3016 caracteres)...
# Dividindo texto da página 117 do arquivo 'fisica2.pdf' (aprox 3280 caracteres)...
# Dividindo texto da página 118 do arquivo 'fisica2.pdf' (aprox 4067 caracteres)...
# Dividindo texto da página 119 do arquivo 'fisica2.pdf' (aprox 5465 caracteres)...
# Dividindo texto da página 120 do arquivo 'fisica2.pdf' (aprox 4152 caracteres)...
# Dividindo texto da página 121 do arquivo 'fisica2.pdf' (aprox 5104 caracteres)...
# Dividindo texto da página 122 do arquivo 'fisica2.pdf' (aprox 3880 caracteres)...
# Dividindo texto da página 123 do arquivo 'fisica2.pdf' (aprox 3674 caracteres)...
# Dividindo texto da página 124 do arquivo 'fisica2.pdf' (aprox 2751 caracteres)...
# Dividindo texto da página 127 do arquivo 'fisica2.pdf' (aprox 4655 caracteres)...
# Dividindo texto da página 129 do arquivo 'fisica2.pdf' (aprox 2459 caracteres)...
# Dividindo texto da página 130 do arquivo 'fisica2.pdf' (aprox 3310 caracteres)...
# Dividindo texto da página 131 do arquivo 'fisica2.pdf' (aprox 2818 caracteres)...
# Dividindo texto da página 133 do arquivo 'fisica2.pdf' (aprox 3207 caracteres)...
# Dividindo texto da página 134 do arquivo 'fisica2.pdf' (aprox 3252 caracteres)...
# Dividindo texto da página 135 do arquivo 'fisica2.pdf' (aprox 4209 caracteres)...
# Dividindo texto da página 136 do arquivo 'fisica2.pdf' (aprox 5991 caracteres)...
# Dividindo texto da página 137 do arquivo 'fisica2.pdf' (aprox 3076 caracteres)...
# Dividindo texto da página 138 do arquivo 'fisica2.pdf' (aprox 4880 caracteres)...
# Dividindo texto da página 140 do arquivo 'fisica2.pdf' (aprox 3734 caracteres)...
# Dividindo texto da página 141 do arquivo 'fisica2.pdf' (aprox 3990 caracteres)...
# Dividindo texto da página 142 do arquivo 'fisica2.pdf' (aprox 4773 caracteres)...
# Dividindo texto da página 143 do arquivo 'fisica2.pdf' (aprox 5944 caracteres)...
# Dividindo texto da página 144 do arquivo 'fisica2.pdf' (aprox 5993 caracteres)...
# Dividindo texto da página 145 do arquivo 'fisica2.pdf' (aprox 7615 caracteres)...
# Dividindo texto da página 146 do arquivo 'fisica2.pdf' (aprox 4044 caracteres)...
# Dividindo texto da página 148 do arquivo 'fisica2.pdf' (aprox 4564 caracteres)...
# Dividindo texto da página 149 do arquivo 'fisica2.pdf' (aprox 4124 caracteres)...
# Dividindo texto da página 150 do arquivo 'fisica2.pdf' (aprox 2163 caracteres)...
# Dividindo texto da página 152 do arquivo 'fisica2.pdf' (aprox 3470 caracteres)...
# Dividindo texto da página 153 do arquivo 'fisica2.pdf' (aprox 4337 caracteres)...
# Dividindo texto da página 154 do arquivo 'fisica2.pdf' (aprox 2900 caracteres)...
# Dividindo texto da página 155 do arquivo 'fisica2.pdf' (aprox 3484 caracteres)...
# Dividindo texto da página 156 do arquivo 'fisica2.pdf' (aprox 2704 caracteres)...
# Dividindo texto da página 157 do arquivo 'fisica2.pdf' (aprox 2472 caracteres)...
# Dividindo texto da página 158 do arquivo 'fisica2.pdf' (aprox 3781 caracteres)...
# Dividindo texto da página 159 do arquivo 'fisica2.pdf' (aprox 3142 caracteres)...
# Dividindo texto da página 160 do arquivo 'fisica2.pdf' (aprox 5089 caracteres)...
# Dividindo texto da página 161 do arquivo 'fisica2.pdf' (aprox 4477 caracteres)...
# Dividindo texto da página 162 do arquivo 'fisica2.pdf' (aprox 5261 caracteres)...
# Dividindo texto da página 163 do arquivo 'fisica2.pdf' (aprox 3277 caracteres)...
# Dividindo texto da página 164 do arquivo 'fisica2.pdf' (aprox 2727 caracteres)...
# Dividindo texto da página 165 do arquivo 'fisica2.pdf' (aprox 5932 caracteres)...
# Dividindo texto da página 166 do arquivo 'fisica2.pdf' (aprox 4963 caracteres)...
# Dividindo texto da página 167 do arquivo 'fisica2.pdf' (aprox 5781 caracteres)...
# Dividindo texto da página 168 do arquivo 'fisica2.pdf' (aprox 4942 caracteres)...
# Dividindo texto da página 169 do arquivo 'fisica2.pdf' (aprox 7499 caracteres)...
# Dividindo texto da página 170 do arquivo 'fisica2.pdf' (aprox 5201 caracteres)...
# Dividindo texto da página 171 do arquivo 'fisica2.pdf' (aprox 2283 caracteres)...
# Dividindo texto da página 172 do arquivo 'fisica2.pdf' (aprox 4788 caracteres)...
# Dividindo texto da página 173 do arquivo 'fisica2.pdf' (aprox 2696 caracteres)...
# Dividindo texto da página 174 do arquivo 'fisica2.pdf' (aprox 3797 caracteres)...
# Dividindo texto da página 175 do arquivo 'fisica2.pdf' (aprox 3161 caracteres)...
# Dividindo texto da página 176 do arquivo 'fisica2.pdf' (aprox 3104 caracteres)...
# Dividindo texto da página 177 do arquivo 'fisica2.pdf' (aprox 2638 caracteres)...
# Dividindo texto da página 178 do arquivo 'fisica2.pdf' (aprox 3045 caracteres)...
# Dividindo texto da página 179 do arquivo 'fisica2.pdf' (aprox 3030 caracteres)...
# Dividindo texto da página 180 do arquivo 'fisica2.pdf' (aprox 3427 caracteres)...
# Dividindo texto da página 181 do arquivo 'fisica2.pdf' (aprox 5160 caracteres)...
# Dividindo texto da página 182 do arquivo 'fisica2.pdf' (aprox 2831 caracteres)...
# Dividindo texto da página 183 do arquivo 'fisica2.pdf' (aprox 2794 caracteres)...
# Dividindo texto da página 184 do arquivo 'fisica2.pdf' (aprox 3291 caracteres)...
# Dividindo texto da página 185 do arquivo 'fisica2.pdf' (aprox 3916 caracteres)...
# Dividindo texto da página 186 do arquivo 'fisica2.pdf' (aprox 2851 caracteres)...
# Dividindo texto da página 187 do arquivo 'fisica2.pdf' (aprox 2913 caracteres)...
# Dividindo texto da página 188 do arquivo 'fisica2.pdf' (aprox 2394 caracteres)...
# Dividindo texto da página 189 do arquivo 'fisica2.pdf' (aprox 3781 caracteres)...
# Dividindo texto da página 190 do arquivo 'fisica2.pdf' (aprox 4435 caracteres)...
# Dividindo texto da página 191 do arquivo 'fisica2.pdf' (aprox 3285 caracteres)...
# Dividindo texto da página 192 do arquivo 'fisica2.pdf' (aprox 5024 caracteres)...
# Dividindo texto da página 193 do arquivo 'fisica2.pdf' (aprox 2814 caracteres)...
# Dividindo texto da página 194 do arquivo 'fisica2.pdf' (aprox 2977 caracteres)...
# Dividindo texto da página 195 do arquivo 'fisica2.pdf' (aprox 2277 caracteres)...
# Dividindo texto da página 196 do arquivo 'fisica2.pdf' (aprox 5002 caracteres)...
# Dividindo texto da página 197 do arquivo 'fisica2.pdf' (aprox 3507 caracteres)...
# Dividindo texto da página 198 do arquivo 'fisica2.pdf' (aprox 2962 caracteres)...
# Dividindo texto da página 199 do arquivo 'fisica2.pdf' (aprox 4069 caracteres)...
# Dividindo texto da página 200 do arquivo 'fisica2.pdf' (aprox 4215 caracteres)...
# Dividindo texto da página 201 do arquivo 'fisica2.pdf' (aprox 2020 caracteres)...
# Dividindo texto da página 202 do arquivo 'fisica2.pdf' (aprox 2923 caracteres)...
# Dividindo texto da página 203 do arquivo 'fisica2.pdf' (aprox 2883 caracteres)...
# Dividindo texto da página 204 do arquivo 'fisica2.pdf' (aprox 3589 caracteres)...
# Dividindo texto da página 205 do arquivo 'fisica2.pdf' (aprox 5624 caracteres)...
# Dividindo texto da página 206 do arquivo 'fisica2.pdf' (aprox 2774 caracteres)...
# Dividindo texto da página 207 do arquivo 'fisica2.pdf' (aprox 3681 caracteres)...
# Dividindo texto da página 208 do arquivo 'fisica2.pdf' (aprox 2805 caracteres)...
# Dividindo texto da página 209 do arquivo 'fisica2.pdf' (aprox 3645 caracteres)...
# Dividindo texto da página 210 do arquivo 'fisica2.pdf' (aprox 4654 caracteres)...
# Dividindo texto da página 211 do arquivo 'fisica2.pdf' (aprox 3104 caracteres)...
# Dividindo texto da página 212 do arquivo 'fisica2.pdf' (aprox 5538 caracteres)...
# Dividindo texto da página 213 do arquivo 'fisica2.pdf' (aprox 5528 caracteres)...
# Dividindo texto da página 214 do arquivo 'fisica2.pdf' (aprox 4205 caracteres)...
# Dividindo texto da página 215 do arquivo 'fisica2.pdf' (aprox 7846 caracteres)...
# Dividindo texto da página 216 do arquivo 'fisica2.pdf' (aprox 4648 caracteres)...
# Adicionados 544 chunks do arquivo 'fisica2.pdf'.
#
# --- Processando arquivo: fisica3.pdf ---
# Lendo PDF: 'fisica3.pdf' com 296 páginas.
# Texto extraído de 296 páginas do arquivo 'fisica3.pdf'.
# Dividindo texto da página 1 do arquivo 'fisica3.pdf' (aprox 2640 caracteres)...
# Dividindo texto da página 2 do arquivo 'fisica3.pdf' (aprox 3927 caracteres)...
# Dividindo texto da página 3 do arquivo 'fisica3.pdf' (aprox 4718 caracteres)...
# Dividindo texto da página 4 do arquivo 'fisica3.pdf' (aprox 7093 caracteres)...
# Dividindo texto da página 5 do arquivo 'fisica3.pdf' (aprox 11663 caracteres)...
# Dividindo texto da página 6 do arquivo 'fisica3.pdf' (aprox 3702 caracteres)...
# Dividindo texto da página 7 do arquivo 'fisica3.pdf' (aprox 3092 caracteres)...
# Dividindo texto da página 8 do arquivo 'fisica3.pdf' (aprox 3551 caracteres)...
# Dividindo texto da página 9 do arquivo 'fisica3.pdf' (aprox 3388 caracteres)...
# Dividindo texto da página 10 do arquivo 'fisica3.pdf' (aprox 3772 caracteres)...
# Dividindo texto da página 11 do arquivo 'fisica3.pdf' (aprox 3283 caracteres)...
# Dividindo texto da página 12 do arquivo 'fisica3.pdf' (aprox 2058 caracteres)...
# Dividindo texto da página 14 do arquivo 'fisica3.pdf' (aprox 2390 caracteres)...
# Dividindo texto da página 16 do arquivo 'fisica3.pdf' (aprox 2637 caracteres)...
# Dividindo texto da página 17 do arquivo 'fisica3.pdf' (aprox 6726 caracteres)...
# Dividindo texto da página 19 do arquivo 'fisica3.pdf' (aprox 3542 caracteres)...
# Dividindo texto da página 20 do arquivo 'fisica3.pdf' (aprox 3223 caracteres)...
# Dividindo texto da página 21 do arquivo 'fisica3.pdf' (aprox 3486 caracteres)...
# Dividindo texto da página 22 do arquivo 'fisica3.pdf' (aprox 4063 caracteres)...
# Dividindo texto da página 23 do arquivo 'fisica3.pdf' (aprox 3716 caracteres)...
# Dividindo texto da página 24 do arquivo 'fisica3.pdf' (aprox 2389 caracteres)...
# Dividindo texto da página 25 do arquivo 'fisica3.pdf' (aprox 2542 caracteres)...
# Dividindo texto da página 29 do arquivo 'fisica3.pdf' (aprox 3293 caracteres)...
# Dividindo texto da página 31 do arquivo 'fisica3.pdf' (aprox 3138 caracteres)...
# Dividindo texto da página 32 do arquivo 'fisica3.pdf' (aprox 3571 caracteres)...
# Dividindo texto da página 33 do arquivo 'fisica3.pdf' (aprox 2818 caracteres)...
# Dividindo texto da página 34 do arquivo 'fisica3.pdf' (aprox 3099 caracteres)...
# Dividindo texto da página 35 do arquivo 'fisica3.pdf' (aprox 4025 caracteres)...
# Dividindo texto da página 36 do arquivo 'fisica3.pdf' (aprox 5666 caracteres)...
# Dividindo texto da página 37 do arquivo 'fisica3.pdf' (aprox 4221 caracteres)...
# Dividindo texto da página 38 do arquivo 'fisica3.pdf' (aprox 3929 caracteres)...
# Dividindo texto da página 39 do arquivo 'fisica3.pdf' (aprox 3924 caracteres)...
# Dividindo texto da página 40 do arquivo 'fisica3.pdf' (aprox 6075 caracteres)...
# Dividindo texto da página 41 do arquivo 'fisica3.pdf' (aprox 6029 caracteres)...
# Dividindo texto da página 42 do arquivo 'fisica3.pdf' (aprox 3729 caracteres)...
# Dividindo texto da página 43 do arquivo 'fisica3.pdf' (aprox 5466 caracteres)...
# Dividindo texto da página 44 do arquivo 'fisica3.pdf' (aprox 4335 caracteres)...
# Dividindo texto da página 45 do arquivo 'fisica3.pdf' (aprox 2904 caracteres)...
# Dividindo texto da página 46 do arquivo 'fisica3.pdf' (aprox 2124 caracteres)...
# Dividindo texto da página 48 do arquivo 'fisica3.pdf' (aprox 3130 caracteres)...
# Dividindo texto da página 49 do arquivo 'fisica3.pdf' (aprox 2825 caracteres)...
# Dividindo texto da página 50 do arquivo 'fisica3.pdf' (aprox 4581 caracteres)...
# Dividindo texto da página 51 do arquivo 'fisica3.pdf' (aprox 2118 caracteres)...
# Dividindo texto da página 54 do arquivo 'fisica3.pdf' (aprox 2985 caracteres)...
# Dividindo texto da página 55 do arquivo 'fisica3.pdf' (aprox 2837 caracteres)...
# Dividindo texto da página 56 do arquivo 'fisica3.pdf' (aprox 3508 caracteres)...
# Dividindo texto da página 57 do arquivo 'fisica3.pdf' (aprox 3000 caracteres)...
# Dividindo texto da página 58 do arquivo 'fisica3.pdf' (aprox 3664 caracteres)...
# Dividindo texto da página 59 do arquivo 'fisica3.pdf' (aprox 2602 caracteres)...
# Dividindo texto da página 60 do arquivo 'fisica3.pdf' (aprox 2906 caracteres)...
# Dividindo texto da página 61 do arquivo 'fisica3.pdf' (aprox 2032 caracteres)...
# Dividindo texto da página 62 do arquivo 'fisica3.pdf' (aprox 3808 caracteres)...
# Dividindo texto da página 63 do arquivo 'fisica3.pdf' (aprox 5515 caracteres)...
# Dividindo texto da página 64 do arquivo 'fisica3.pdf' (aprox 4879 caracteres)...
# Dividindo texto da página 65 do arquivo 'fisica3.pdf' (aprox 3404 caracteres)...
# Dividindo texto da página 66 do arquivo 'fisica3.pdf' (aprox 4052 caracteres)...
# Dividindo texto da página 68 do arquivo 'fisica3.pdf' (aprox 2327 caracteres)...
# Dividindo texto da página 69 do arquivo 'fisica3.pdf' (aprox 3233 caracteres)...
# Dividindo texto da página 70 do arquivo 'fisica3.pdf' (aprox 2362 caracteres)...
# Dividindo texto da página 71 do arquivo 'fisica3.pdf' (aprox 3148 caracteres)...
# Dividindo texto da página 72 do arquivo 'fisica3.pdf' (aprox 2236 caracteres)...
# Dividindo texto da página 73 do arquivo 'fisica3.pdf' (aprox 2518 caracteres)...
# Dividindo texto da página 74 do arquivo 'fisica3.pdf' (aprox 2128 caracteres)...
# Dividindo texto da página 75 do arquivo 'fisica3.pdf' (aprox 4251 caracteres)...
# Dividindo texto da página 76 do arquivo 'fisica3.pdf' (aprox 2240 caracteres)...
# Dividindo texto da página 77 do arquivo 'fisica3.pdf' (aprox 3288 caracteres)...
# Dividindo texto da página 78 do arquivo 'fisica3.pdf' (aprox 3093 caracteres)...
# Dividindo texto da página 79 do arquivo 'fisica3.pdf' (aprox 2331 caracteres)...
# Dividindo texto da página 80 do arquivo 'fisica3.pdf' (aprox 2736 caracteres)...
# Dividindo texto da página 81 do arquivo 'fisica3.pdf' (aprox 4149 caracteres)...
# Dividindo texto da página 82 do arquivo 'fisica3.pdf' (aprox 4111 caracteres)...
# Dividindo texto da página 83 do arquivo 'fisica3.pdf' (aprox 5378 caracteres)...
# Dividindo texto da página 84 do arquivo 'fisica3.pdf' (aprox 4648 caracteres)...
# Dividindo texto da página 85 do arquivo 'fisica3.pdf' (aprox 5407 caracteres)...
# Dividindo texto da página 86 do arquivo 'fisica3.pdf' (aprox 3443 caracteres)...
# Dividindo texto da página 87 do arquivo 'fisica3.pdf' (aprox 4930 caracteres)...
# Dividindo texto da página 88 do arquivo 'fisica3.pdf' (aprox 4338 caracteres)...
# Dividindo texto da página 89 do arquivo 'fisica3.pdf' (aprox 4598 caracteres)...
# Dividindo texto da página 90 do arquivo 'fisica3.pdf' (aprox 4419 caracteres)...
# Dividindo texto da página 91 do arquivo 'fisica3.pdf' (aprox 4552 caracteres)...
# Dividindo texto da página 92 do arquivo 'fisica3.pdf' (aprox 2697 caracteres)...
# Dividindo texto da página 93 do arquivo 'fisica3.pdf' (aprox 4127 caracteres)...
# Dividindo texto da página 94 do arquivo 'fisica3.pdf' (aprox 2244 caracteres)...
# Dividindo texto da página 95 do arquivo 'fisica3.pdf' (aprox 2448 caracteres)...
# Dividindo texto da página 96 do arquivo 'fisica3.pdf' (aprox 4126 caracteres)...
# Dividindo texto da página 97 do arquivo 'fisica3.pdf' (aprox 3598 caracteres)...
# Dividindo texto da página 98 do arquivo 'fisica3.pdf' (aprox 5089 caracteres)...
# Dividindo texto da página 99 do arquivo 'fisica3.pdf' (aprox 2956 caracteres)...
# Dividindo texto da página 100 do arquivo 'fisica3.pdf' (aprox 4618 caracteres)...
# Dividindo texto da página 101 do arquivo 'fisica3.pdf' (aprox 2184 caracteres)...
# Dividindo texto da página 102 do arquivo 'fisica3.pdf' (aprox 3002 caracteres)...
# Dividindo texto da página 103 do arquivo 'fisica3.pdf' (aprox 2509 caracteres)...
# Dividindo texto da página 105 do arquivo 'fisica3.pdf' (aprox 3470 caracteres)...
# Dividindo texto da página 106 do arquivo 'fisica3.pdf' (aprox 4826 caracteres)...
# Dividindo texto da página 107 do arquivo 'fisica3.pdf' (aprox 4890 caracteres)...
# Dividindo texto da página 108 do arquivo 'fisica3.pdf' (aprox 5903 caracteres)...
# Dividindo texto da página 109 do arquivo 'fisica3.pdf' (aprox 6033 caracteres)...
# Dividindo texto da página 110 do arquivo 'fisica3.pdf' (aprox 3375 caracteres)...
# Dividindo texto da página 112 do arquivo 'fisica3.pdf' (aprox 3782 caracteres)...
# Dividindo texto da página 113 do arquivo 'fisica3.pdf' (aprox 3616 caracteres)...
# Dividindo texto da página 114 do arquivo 'fisica3.pdf' (aprox 2716 caracteres)...
# Dividindo texto da página 115 do arquivo 'fisica3.pdf' (aprox 3819 caracteres)...
# Dividindo texto da página 116 do arquivo 'fisica3.pdf' (aprox 2872 caracteres)...
# Dividindo texto da página 117 do arquivo 'fisica3.pdf' (aprox 3968 caracteres)...
# Dividindo texto da página 118 do arquivo 'fisica3.pdf' (aprox 2378 caracteres)...
# Dividindo texto da página 119 do arquivo 'fisica3.pdf' (aprox 3076 caracteres)...
# Dividindo texto da página 120 do arquivo 'fisica3.pdf' (aprox 3744 caracteres)...
# Dividindo texto da página 121 do arquivo 'fisica3.pdf' (aprox 3124 caracteres)...
# Dividindo texto da página 122 do arquivo 'fisica3.pdf' (aprox 2752 caracteres)...
# Dividindo texto da página 123 do arquivo 'fisica3.pdf' (aprox 2373 caracteres)...
# Dividindo texto da página 126 do arquivo 'fisica3.pdf' (aprox 5154 caracteres)...
# Dividindo texto da página 127 do arquivo 'fisica3.pdf' (aprox 3749 caracteres)...
# Dividindo texto da página 128 do arquivo 'fisica3.pdf' (aprox 5542 caracteres)...
# Dividindo texto da página 129 do arquivo 'fisica3.pdf' (aprox 4186 caracteres)...
# Dividindo texto da página 132 do arquivo 'fisica3.pdf' (aprox 4357 caracteres)...
# Dividindo texto da página 133 do arquivo 'fisica3.pdf' (aprox 3212 caracteres)...
# Dividindo texto da página 134 do arquivo 'fisica3.pdf' (aprox 5417 caracteres)...
# Dividindo texto da página 135 do arquivo 'fisica3.pdf' (aprox 3757 caracteres)...
# Dividindo texto da página 136 do arquivo 'fisica3.pdf' (aprox 3661 caracteres)...
# Dividindo texto da página 137 do arquivo 'fisica3.pdf' (aprox 2650 caracteres)...
# Dividindo texto da página 138 do arquivo 'fisica3.pdf' (aprox 4170 caracteres)...
# Dividindo texto da página 139 do arquivo 'fisica3.pdf' (aprox 4511 caracteres)...
# Dividindo texto da página 140 do arquivo 'fisica3.pdf' (aprox 2726 caracteres)...
# Dividindo texto da página 141 do arquivo 'fisica3.pdf' (aprox 3026 caracteres)...
# Dividindo texto da página 142 do arquivo 'fisica3.pdf' (aprox 6033 caracteres)...
# Dividindo texto da página 143 do arquivo 'fisica3.pdf' (aprox 4713 caracteres)...
# Dividindo texto da página 144 do arquivo 'fisica3.pdf' (aprox 4928 caracteres)...
# Dividindo texto da página 145 do arquivo 'fisica3.pdf' (aprox 4971 caracteres)...
# Dividindo texto da página 146 do arquivo 'fisica3.pdf' (aprox 4890 caracteres)...
# Dividindo texto da página 147 do arquivo 'fisica3.pdf' (aprox 4916 caracteres)...
# Dividindo texto da página 148 do arquivo 'fisica3.pdf' (aprox 5894 caracteres)...
# Dividindo texto da página 149 do arquivo 'fisica3.pdf' (aprox 5438 caracteres)...
# Dividindo texto da página 150 do arquivo 'fisica3.pdf' (aprox 2170 caracteres)...
# Dividindo texto da página 152 do arquivo 'fisica3.pdf' (aprox 3341 caracteres)...
# Dividindo texto da página 153 do arquivo 'fisica3.pdf' (aprox 2528 caracteres)...
# Dividindo texto da página 154 do arquivo 'fisica3.pdf' (aprox 3770 caracteres)...
# Dividindo texto da página 155 do arquivo 'fisica3.pdf' (aprox 2624 caracteres)...
# Dividindo texto da página 156 do arquivo 'fisica3.pdf' (aprox 4014 caracteres)...
# Dividindo texto da página 157 do arquivo 'fisica3.pdf' (aprox 3226 caracteres)...
# Dividindo texto da página 158 do arquivo 'fisica3.pdf' (aprox 3102 caracteres)...
# Dividindo texto da página 159 do arquivo 'fisica3.pdf' (aprox 3626 caracteres)...
# Dividindo texto da página 160 do arquivo 'fisica3.pdf' (aprox 2584 caracteres)...
# Dividindo texto da página 161 do arquivo 'fisica3.pdf' (aprox 2400 caracteres)...
# Dividindo texto da página 162 do arquivo 'fisica3.pdf' (aprox 3344 caracteres)...
# Dividindo texto da página 163 do arquivo 'fisica3.pdf' (aprox 3642 caracteres)...
# Dividindo texto da página 164 do arquivo 'fisica3.pdf' (aprox 2782 caracteres)...
# Dividindo texto da página 165 do arquivo 'fisica3.pdf' (aprox 2728 caracteres)...
# Dividindo texto da página 168 do arquivo 'fisica3.pdf' (aprox 2160 caracteres)...
# Dividindo texto da página 170 do arquivo 'fisica3.pdf' (aprox 3068 caracteres)...
# Dividindo texto da página 173 do arquivo 'fisica3.pdf' (aprox 3112 caracteres)...
# Dividindo texto da página 174 do arquivo 'fisica3.pdf' (aprox 3802 caracteres)...
# Dividindo texto da página 175 do arquivo 'fisica3.pdf' (aprox 6118 caracteres)...
# Dividindo texto da página 176 do arquivo 'fisica3.pdf' (aprox 2860 caracteres)...
# Dividindo texto da página 177 do arquivo 'fisica3.pdf' (aprox 3154 caracteres)...
# Dividindo texto da página 178 do arquivo 'fisica3.pdf' (aprox 4409 caracteres)...
# Dividindo texto da página 179 do arquivo 'fisica3.pdf' (aprox 4332 caracteres)...
# Dividindo texto da página 180 do arquivo 'fisica3.pdf' (aprox 2724 caracteres)...
# Dividindo texto da página 184 do arquivo 'fisica3.pdf' (aprox 3117 caracteres)...
# Dividindo texto da página 186 do arquivo 'fisica3.pdf' (aprox 2531 caracteres)...
# Dividindo texto da página 187 do arquivo 'fisica3.pdf' (aprox 3499 caracteres)...
# Dividindo texto da página 188 do arquivo 'fisica3.pdf' (aprox 2120 caracteres)...
# Dividindo texto da página 189 do arquivo 'fisica3.pdf' (aprox 2633 caracteres)...
# Dividindo texto da página 190 do arquivo 'fisica3.pdf' (aprox 2319 caracteres)...
# Dividindo texto da página 194 do arquivo 'fisica3.pdf' (aprox 2260 caracteres)...
# Dividindo texto da página 195 do arquivo 'fisica3.pdf' (aprox 4892 caracteres)...
# Dividindo texto da página 196 do arquivo 'fisica3.pdf' (aprox 4621 caracteres)...
# Dividindo texto da página 197 do arquivo 'fisica3.pdf' (aprox 3242 caracteres)...
# Dividindo texto da página 198 do arquivo 'fisica3.pdf' (aprox 2601 caracteres)...
# Dividindo texto da página 199 do arquivo 'fisica3.pdf' (aprox 3298 caracteres)...
# Dividindo texto da página 200 do arquivo 'fisica3.pdf' (aprox 2432 caracteres)...
# Dividindo texto da página 202 do arquivo 'fisica3.pdf' (aprox 2752 caracteres)...
# Dividindo texto da página 203 do arquivo 'fisica3.pdf' (aprox 4110 caracteres)...
# Dividindo texto da página 204 do arquivo 'fisica3.pdf' (aprox 2380 caracteres)...
# Dividindo texto da página 205 do arquivo 'fisica3.pdf' (aprox 2621 caracteres)...
# Dividindo texto da página 206 do arquivo 'fisica3.pdf' (aprox 3266 caracteres)...
# Dividindo texto da página 207 do arquivo 'fisica3.pdf' (aprox 2252 caracteres)...
# Dividindo texto da página 208 do arquivo 'fisica3.pdf' (aprox 2556 caracteres)...
# Dividindo texto da página 210 do arquivo 'fisica3.pdf' (aprox 2924 caracteres)...
# Dividindo texto da página 211 do arquivo 'fisica3.pdf' (aprox 2984 caracteres)...
# Dividindo texto da página 213 do arquivo 'fisica3.pdf' (aprox 2364 caracteres)...
# Dividindo texto da página 214 do arquivo 'fisica3.pdf' (aprox 2142 caracteres)...
# Dividindo texto da página 215 do arquivo 'fisica3.pdf' (aprox 2351 caracteres)...
# Dividindo texto da página 216 do arquivo 'fisica3.pdf' (aprox 2165 caracteres)...
# Dividindo texto da página 217 do arquivo 'fisica3.pdf' (aprox 2741 caracteres)...
# Dividindo texto da página 219 do arquivo 'fisica3.pdf' (aprox 2485 caracteres)...
# Dividindo texto da página 220 do arquivo 'fisica3.pdf' (aprox 2909 caracteres)...
# Dividindo texto da página 222 do arquivo 'fisica3.pdf' (aprox 3861 caracteres)...
# Dividindo texto da página 223 do arquivo 'fisica3.pdf' (aprox 2457 caracteres)...
# Dividindo texto da página 224 do arquivo 'fisica3.pdf' (aprox 2117 caracteres)...
# Dividindo texto da página 226 do arquivo 'fisica3.pdf' (aprox 7016 caracteres)...
# Dividindo texto da página 227 do arquivo 'fisica3.pdf' (aprox 4928 caracteres)...
# Dividindo texto da página 228 do arquivo 'fisica3.pdf' (aprox 4567 caracteres)...
# Dividindo texto da página 229 do arquivo 'fisica3.pdf' (aprox 3127 caracteres)...
# Dividindo texto da página 230 do arquivo 'fisica3.pdf' (aprox 5403 caracteres)...
# Dividindo texto da página 231 do arquivo 'fisica3.pdf' (aprox 4129 caracteres)...
# Dividindo texto da página 232 do arquivo 'fisica3.pdf' (aprox 3507 caracteres)...
# Dividindo texto da página 233 do arquivo 'fisica3.pdf' (aprox 3782 caracteres)...
# Dividindo texto da página 234 do arquivo 'fisica3.pdf' (aprox 4279 caracteres)...
# Dividindo texto da página 235 do arquivo 'fisica3.pdf' (aprox 4404 caracteres)...
# Dividindo texto da página 236 do arquivo 'fisica3.pdf' (aprox 2310 caracteres)...
# Dividindo texto da página 237 do arquivo 'fisica3.pdf' (aprox 2787 caracteres)...
# Dividindo texto da página 240 do arquivo 'fisica3.pdf' (aprox 2524 caracteres)...
# Dividindo texto da página 241 do arquivo 'fisica3.pdf' (aprox 3955 caracteres)...
# Dividindo texto da página 243 do arquivo 'fisica3.pdf' (aprox 2677 caracteres)...
# Dividindo texto da página 244 do arquivo 'fisica3.pdf' (aprox 2066 caracteres)...
# Dividindo texto da página 245 do arquivo 'fisica3.pdf' (aprox 4472 caracteres)...
# Dividindo texto da página 246 do arquivo 'fisica3.pdf' (aprox 2369 caracteres)...
# Dividindo texto da página 247 do arquivo 'fisica3.pdf' (aprox 4047 caracteres)...
# Dividindo texto da página 248 do arquivo 'fisica3.pdf' (aprox 3311 caracteres)...
# Dividindo texto da página 249 do arquivo 'fisica3.pdf' (aprox 2740 caracteres)...
# Dividindo texto da página 250 do arquivo 'fisica3.pdf' (aprox 6778 caracteres)...
# Dividindo texto da página 251 do arquivo 'fisica3.pdf' (aprox 5305 caracteres)...
# Dividindo texto da página 252 do arquivo 'fisica3.pdf' (aprox 3018 caracteres)...
# Dividindo texto da página 253 do arquivo 'fisica3.pdf' (aprox 2987 caracteres)...
# Dividindo texto da página 256 do arquivo 'fisica3.pdf' (aprox 3227 caracteres)...
# Dividindo texto da página 257 do arquivo 'fisica3.pdf' (aprox 2799 caracteres)...
# Dividindo texto da página 258 do arquivo 'fisica3.pdf' (aprox 2925 caracteres)...
# Dividindo texto da página 259 do arquivo 'fisica3.pdf' (aprox 2100 caracteres)...
# Dividindo texto da página 260 do arquivo 'fisica3.pdf' (aprox 3359 caracteres)...
# Dividindo texto da página 261 do arquivo 'fisica3.pdf' (aprox 2057 caracteres)...
# Dividindo texto da página 262 do arquivo 'fisica3.pdf' (aprox 2745 caracteres)...
# Dividindo texto da página 263 do arquivo 'fisica3.pdf' (aprox 3094 caracteres)...
# Dividindo texto da página 264 do arquivo 'fisica3.pdf' (aprox 2334 caracteres)...
# Dividindo texto da página 265 do arquivo 'fisica3.pdf' (aprox 2117 caracteres)...
# Dividindo texto da página 266 do arquivo 'fisica3.pdf' (aprox 3671 caracteres)...
# Dividindo texto da página 267 do arquivo 'fisica3.pdf' (aprox 2372 caracteres)...
# Dividindo texto da página 268 do arquivo 'fisica3.pdf' (aprox 3978 caracteres)...
# Dividindo texto da página 269 do arquivo 'fisica3.pdf' (aprox 2709 caracteres)...
# Dividindo texto da página 270 do arquivo 'fisica3.pdf' (aprox 3624 caracteres)...
# Dividindo texto da página 271 do arquivo 'fisica3.pdf' (aprox 3182 caracteres)...
# Dividindo texto da página 272 do arquivo 'fisica3.pdf' (aprox 3644 caracteres)...
# Dividindo texto da página 273 do arquivo 'fisica3.pdf' (aprox 3774 caracteres)...
# Dividindo texto da página 274 do arquivo 'fisica3.pdf' (aprox 2369 caracteres)...
# Dividindo texto da página 275 do arquivo 'fisica3.pdf' (aprox 2957 caracteres)...
# Dividindo texto da página 276 do arquivo 'fisica3.pdf' (aprox 2068 caracteres)...
# Dividindo texto da página 277 do arquivo 'fisica3.pdf' (aprox 2865 caracteres)...
# Dividindo texto da página 278 do arquivo 'fisica3.pdf' (aprox 3404 caracteres)...
# Dividindo texto da página 279 do arquivo 'fisica3.pdf' (aprox 4080 caracteres)...
# Dividindo texto da página 280 do arquivo 'fisica3.pdf' (aprox 2820 caracteres)...
# Dividindo texto da página 281 do arquivo 'fisica3.pdf' (aprox 2075 caracteres)...
# Dividindo texto da página 282 do arquivo 'fisica3.pdf' (aprox 2601 caracteres)...
# Dividindo texto da página 283 do arquivo 'fisica3.pdf' (aprox 5143 caracteres)...
# Dividindo texto da página 284 do arquivo 'fisica3.pdf' (aprox 3199 caracteres)...
# Dividindo texto da página 285 do arquivo 'fisica3.pdf' (aprox 2637 caracteres)...
# Dividindo texto da página 286 do arquivo 'fisica3.pdf' (aprox 2402 caracteres)...
# Dividindo texto da página 288 do arquivo 'fisica3.pdf' (aprox 3548 caracteres)...
# Dividindo texto da página 289 do arquivo 'fisica3.pdf' (aprox 4330 caracteres)...
# Dividindo texto da página 290 do arquivo 'fisica3.pdf' (aprox 3430 caracteres)...
# Dividindo texto da página 291 do arquivo 'fisica3.pdf' (aprox 3477 caracteres)...
# Dividindo texto da página 292 do arquivo 'fisica3.pdf' (aprox 5847 caracteres)...
# Dividindo texto da página 293 do arquivo 'fisica3.pdf' (aprox 4698 caracteres)...
# Dividindo texto da página 294 do arquivo 'fisica3.pdf' (aprox 3706 caracteres)...
# Dividindo texto da página 295 do arquivo 'fisica3.pdf' (aprox 2802 caracteres)...
# Dividindo texto da página 296 do arquivo 'fisica3.pdf' (aprox 3582 caracteres)...
# Adicionados 650 chunks do arquivo 'fisica3.pdf'.
#
# Total de 1264 chunks de texto preparados de 3 arquivo(s) PDF.
#
# Exemplo do primeiro chunk formatado:
#   texto_original: CENTRO FEDERAL DE EDUCAÇÃO TECNOLÓGICA DE MINAS GERAIS
# UNIDADE VARGINHA
#  DEPARTAMENTO DE FORMAÇÃO GERAL
#
#
#
#
# APOSTILA DE FÍSICA
# PRÓ-TÉCNICO
#
#
#
#
#
# Elaborada por:           Raphaella Bahia...
#   pagina: 1...
#   arquivo_origem: Apostila-Física.pdf...
#
# --- Preparação dos dados de múltiplos PDFs concluída. ---

# %%
# CÉLULA 6 -- Chamada da função gerar_e_armazenar_embeddings ==> Geração e armazenamento de embeddings no banco de dados vetorial → qdrant

if qdrant_client and chunks_de_texto and GOOGLE_AI_API_KEY:
    gerar_e_armazenar_embeddings_gemini(
        text_chunks_dicts=chunks_de_texto,  
        collection_name=COLLECTION_NAME,
        q_client=qdrant_client,
        gemini_model=GEMINI_EMBEDDING_MODEL
        # Os argumentos opcionais qdrant_upsert_batch_size e gemini_api_call_batch_size 
        # usarão seus valores padrão definidos na função, se não forem especificados aqui.
    )
elif not qdrant_client:
    print("Execução abortada: Cliente Qdrant não está inicializado.")
elif not GOOGLE_AI_API_KEY: # Certifique-se que GOOGLE_AI_API_KEY está definida
    print("Execução abortada: Chave da API do Google AI não configurada.")
elif not chunks_de_texto: # Adicionada verificação explícita para clareza
    print("Execução abortada: `chunks_de_texto` estão vazios ou não definidos.")
else: # Caso genérico, embora as condições acima devam cobrir os principais
    print("Execução abortada por motivo desconhecido ou condição não atendida.")
# Out:
# Iniciando geração e armazenamento de embeddings com Gemini para 1264 chunks...
#
# Processando lote de 30 textos válidos para API Gemini (de 30 chunks originais no lote)...
#   Lote da API Gemini processado. 30 embeddings gerados.
#   Aguardando para a próxima chamada à API Gemini...
#
# Processando lote de 30 textos válidos para API Gemini (de 30 chunks originais no lote)...
#   Lote da API Gemini processado. 30 embeddings gerados.
#   Aguardando para a próxima chamada à API Gemini...
#
# Processando lote de 30 textos válidos para API Gemini (de 30 chunks originais no lote)...
#   Lote da API Gemini processado. 30 embeddings gerados.
#   Aguardando para a próxima chamada à API Gemini...
#
# Processando lote de 30 textos válidos para API Gemini (de 30 chunks originais no lote)...
#   Lote da API Gemini processado. 30 embeddings gerados.
#   Enviando 120 pontos para Qdrant...
#   120 pontos enviados ao Qdrant.
#   Aguardando para a próxima chamada à API Gemini...
#
# Progresso Atual: 9.49% (120/1264 chunks avaliados). Tempo total: 32.69s
#
# Processando lote de 30 textos válidos para API Gemini (de 30 chunks originais no lote)...
#   Lote da API Gemini processado. 30 embeddings gerados.
#   Aguardando para a próxima chamada à API Gemini...
#
# Processando lote de 30 textos válidos para API Gemini (de 30 chunks originais no lote)...
#   Lote da API Gemini processado. 30 embeddings gerados.
#   Aguardando para a próxima chamada à API Gemini...
#
# Processando lote de 30 textos válidos para API Gemini (de 30 chunks originais no lote)...
#   Lote da API Gemini processado. 30 embeddings gerados.
#   Aguardando para a próxima chamada à API Gemini...
#
# Processando lote de 30 textos válidos para API Gemini (de 30 chunks originais no lote)...
#   Lote da API Gemini processado. 30 embeddings gerados.
#   Enviando 120 pontos para Qdrant...
#   120 pontos enviados ao Qdrant.
#   Aguardando para a próxima chamada à API Gemini...
#
# Progresso Atual: 18.99% (240/1264 chunks avaliados). Tempo total: 55.45s
#
# Processando lote de 30 textos válidos para API Gemini (de 30 chunks originais no lote)...
#   Lote da API Gemini processado. 30 embeddings gerados.
#   Aguardando para a próxima chamada à API Gemini...
#
# Processando lote de 30 textos válidos para API Gemini (de 30 chunks originais no lote)...
#   Lote da API Gemini processado. 30 embeddings gerados.
#   Aguardando para a próxima chamada à API Gemini...
#
# Processando lote de 30 textos válidos para API Gemini (de 30 chunks originais no lote)...
#   Lote da API Gemini processado. 30 embeddings gerados.
#   Aguardando para a próxima chamada à API Gemini...
#
# Processando lote de 30 textos válidos para API Gemini (de 30 chunks originais no lote)...
#   Lote da API Gemini processado. 30 embeddings gerados.
#   Enviando 120 pontos para Qdrant...
#   120 pontos enviados ao Qdrant.
#   Aguardando para a próxima chamada à API Gemini...
#
# Progresso Atual: 28.48% (360/1264 chunks avaliados). Tempo total: 92.52s
#
# Processando lote de 30 textos válidos para API Gemini (de 30 chunks originais no lote)...
#   Lote da API Gemini processado. 30 embeddings gerados.
#   Aguardando para a próxima chamada à API Gemini...
#
# Processando lote de 30 textos válidos para API Gemini (de 30 chunks originais no lote)...
#   Lote da API Gemini processado. 30 embeddings gerados.
#   Aguardando para a próxima chamada à API Gemini...
#
# Processando lote de 30 textos válidos para API Gemini (de 30 chunks originais no lote)...
#   Lote da API Gemini processado. 30 embeddings gerados.
#   Aguardando para a próxima chamada à API Gemini...
#
# Processando lote de 30 textos válidos para API Gemini (de 30 chunks originais no lote)...
#   Lote da API Gemini processado. 30 embeddings gerados.
#   Enviando 120 pontos para Qdrant...
#   120 pontos enviados ao Qdrant.
#   Aguardando para a próxima chamada à API Gemini...
#
# Progresso Atual: 37.97% (480/1264 chunks avaliados). Tempo total: 119.35s
#
# Processando lote de 30 textos válidos para API Gemini (de 30 chunks originais no lote)...
#   Lote da API Gemini processado. 30 embeddings gerados.
#   Aguardando para a próxima chamada à API Gemini...
#
# Processando lote de 30 textos válidos para API Gemini (de 30 chunks originais no lote)...
#   Lote da API Gemini processado. 30 embeddings gerados.
#   Aguardando para a próxima chamada à API Gemini...
#
# Processando lote de 30 textos válidos para API Gemini (de 30 chunks originais no lote)...
#   Lote da API Gemini processado. 30 embeddings gerados.
#   Aguardando para a próxima chamada à API Gemini...
#
# Processando lote de 30 textos válidos para API Gemini (de 30 chunks originais no lote)...
#   Lote da API Gemini processado. 30 embeddings gerados.
#   Enviando 120 pontos para Qdrant...
#   120 pontos enviados ao Qdrant.
#   Aguardando para a próxima chamada à API Gemini...
#
# Progresso Atual: 47.47% (600/1264 chunks avaliados). Tempo total: 133.34s
#
# Processando lote de 30 textos válidos para API Gemini (de 30 chunks originais no lote)...
#   Lote da API Gemini processado. 30 embeddings gerados.
#   Aguardando para a próxima chamada à API Gemini...
#
# Processando lote de 30 textos válidos para API Gemini (de 30 chunks originais no lote)...
#   Lote da API Gemini processado. 30 embeddings gerados.
#   Aguardando para a próxima chamada à API Gemini...
#
# Processando lote de 30 textos válidos para API Gemini (de 30 chunks originais no lote)...
#   Lote da API Gemini processado. 30 embeddings gerados.
#   Aguardando para a próxima chamada à API Gemini...
#
# Progresso Atual: 54.59% (690/1264 chunks avaliados). Tempo total: 143.67s
#
# Processando lote de 30 textos válidos para API Gemini (de 30 chunks originais no lote)...
#   Lote da API Gemini processado. 30 embeddings gerados.
#   Enviando 120 pontos para Qdrant...
#   120 pontos enviados ao Qdrant.
#   Aguardando para a próxima chamada à API Gemini...
#
# Progresso Atual: 56.96% (720/1264 chunks avaliados). Tempo total: 155.34s
#
# Processando lote de 30 textos válidos para API Gemini (de 30 chunks originais no lote)...
#   Lote da API Gemini processado. 30 embeddings gerados.
#   Aguardando para a próxima chamada à API Gemini...
#
# Processando lote de 30 textos válidos para API Gemini (de 30 chunks originais no lote)...
#   Lote da API Gemini processado. 30 embeddings gerados.
#   Aguardando para a próxima chamada à API Gemini...
#
# Processando lote de 30 textos válidos para API Gemini (de 30 chunks originais no lote)...
#   Lote da API Gemini processado. 30 embeddings gerados.
#   Aguardando para a próxima chamada à API Gemini...
#
# Processando lote de 30 textos válidos para API Gemini (de 30 chunks originais no lote)...
#   Lote da API Gemini processado. 30 embeddings gerados.
#   Enviando 120 pontos para Qdrant...
#   120 pontos enviados ao Qdrant.
#   Aguardando para a próxima chamada à API Gemini...
#
# Progresso Atual: 66.46% (840/1264 chunks avaliados). Tempo total: 171.23s
#
# Processando lote de 30 textos válidos para API Gemini (de 30 chunks originais no lote)...
#   Lote da API Gemini processado. 30 embeddings gerados.
#   Aguardando para a próxima chamada à API Gemini...
#
# Processando lote de 30 textos válidos para API Gemini (de 30 chunks originais no lote)...
#   Lote da API Gemini processado. 30 embeddings gerados.
#   Aguardando para a próxima chamada à API Gemini...
#
# Processando lote de 30 textos válidos para API Gemini (de 30 chunks originais no lote)...
#   Lote da API Gemini processado. 30 embeddings gerados.
#   Aguardando para a próxima chamada à API Gemini...
#
# Processando lote de 30 textos válidos para API Gemini (de 30 chunks originais no lote)...
#   Lote da API Gemini processado. 30 embeddings gerados.
#   Enviando 120 pontos para Qdrant...
#   120 pontos enviados ao Qdrant.
#   Aguardando para a próxima chamada à API Gemini...
#
# Progresso Atual: 75.95% (960/1264 chunks avaliados). Tempo total: 186.47s
#
# Processando lote de 30 textos válidos para API Gemini (de 30 chunks originais no lote)...
#   Lote da API Gemini processado. 30 embeddings gerados.
#   Aguardando para a próxima chamada à API Gemini...
#
# Processando lote de 30 textos válidos para API Gemini (de 30 chunks originais no lote)...
#   Lote da API Gemini processado. 30 embeddings gerados.
#   Aguardando para a próxima chamada à API Gemini...
#
# Processando lote de 30 textos válidos para API Gemini (de 30 chunks originais no lote)...
#   Lote da API Gemini processado. 30 embeddings gerados.
#   Aguardando para a próxima chamada à API Gemini...
#
# Processando lote de 30 textos válidos para API Gemini (de 30 chunks originais no lote)...
#   Lote da API Gemini processado. 30 embeddings gerados.
#   Enviando 120 pontos para Qdrant...
#   120 pontos enviados ao Qdrant.
#   Aguardando para a próxima chamada à API Gemini...
#
# Progresso Atual: 85.44% (1080/1264 chunks avaliados). Tempo total: 208.20s
#
# Processando lote de 30 textos válidos para API Gemini (de 30 chunks originais no lote)...
#   Lote da API Gemini processado. 30 embeddings gerados.
#   Aguardando para a próxima chamada à API Gemini...
#
# Processando lote de 30 textos válidos para API Gemini (de 30 chunks originais no lote)...
#   Lote da API Gemini processado. 30 embeddings gerados.
#   Aguardando para a próxima chamada à API Gemini...
#
# Processando lote de 30 textos válidos para API Gemini (de 30 chunks originais no lote)...
#   Lote da API Gemini processado. 30 embeddings gerados.
#   Aguardando para a próxima chamada à API Gemini...
#
# Processando lote de 30 textos válidos para API Gemini (de 30 chunks originais no lote)...
#   Lote da API Gemini processado. 30 embeddings gerados.
#   Enviando 120 pontos para Qdrant...
#   120 pontos enviados ao Qdrant.
#   Aguardando para a próxima chamada à API Gemini...
#
# Progresso Atual: 94.94% (1200/1264 chunks avaliados). Tempo total: 224.79s
#
# Processando lote de 30 textos válidos para API Gemini (de 30 chunks originais no lote)...
#   Lote da API Gemini processado. 30 embeddings gerados.
#   Aguardando para a próxima chamada à API Gemini...
#
# Processando lote de 30 textos válidos para API Gemini (de 30 chunks originais no lote)...
#   Lote da API Gemini processado. 30 embeddings gerados.
#   Aguardando para a próxima chamada à API Gemini...
#
# Processando lote de 4 textos válidos para API Gemini (de 4 chunks originais no lote)...
#   Lote da API Gemini processado. 4 embeddings gerados.
#   Enviando 64 pontos para Qdrant...
#   64 pontos enviados ao Qdrant.
#
# Progresso Atual: 100.00% (1264/1264 chunks avaliados). Tempo total: 234.20s
#
# --- Geração e armazenamento de embeddings com Gemini CONCLUÍDOS! Total de 1264 chunks avaliados. ---

# %%
# CÉLULA 7 - Definição das funções buscar_textos_similares (RETRIEVAL) e gerar_resposta_com_contexto (AUGMENTED GENERATION)

import traceback # Import traceback para uso nos blocos except

# Função buscar_textos_similares 
def buscar_textos_similares(query_text, q_client, collection_name, gemini_model_embedding, top_k=3):
    if not q_client or not GOOGLE_AI_API_KEY: # Verifica se o cliente Qdrant e a chave da API (para config do genai) existem
        print("ERRO: Cliente Qdrant ou configuração da API do Google não disponíveis para busca.")
        return []
    try:
        query_embedding_result = genai.embed_content(
            model=gemini_model_embedding, 
            content=query_text,
            task_type="RETRIEVAL_QUERY"
        )
        query_vector = query_embedding_result['embedding']
        
        # Lembre-se do DeprecationWarning que aparecerá.
        search_results = q_client.search(
            collection_name=collection_name,
            query_vector=query_vector,
            limit=top_k,
            with_payload=True
        )
        
        resultados_formatados = []
        for hit in search_results:
            payload = hit.payload if hit.payload else {}
            texto = payload.get("texto_original", payload.get("texto", "Payload sem texto"))
            pagina = payload.get("pagina_pdf", payload.get("pagina", "N/A"))
            arquivo_origem = payload.get("arquivo_origem", "Desconhecido") # Extrai o nome do arquivo
            score = hit.score
            
            resultados_formatados.append({
                "id": hit.id, 
                "score": score, 
                "texto": texto, 
                "pagina": pagina,
                "arquivo_origem": arquivo_origem # Adiciona ao resultado
            })
        return resultados_formatados
    except Exception as e:
        print(f"Erro durante a busca de similaridade: {e}")
        traceback.print_exc()
        return []

# Função para gerar resposta com base no contexto (RAG)
# MODELO_GEMINI_PARA_GERACAO foi definido na Célula 3
# Ex: MODELO_GEMINI_PARA_GERACAO = "gemini-1.5-flash-latest" 

def gerar_resposta_com_contexto(pergunta, chunks_relevantes, nome_modelo_generativo):
    if not chunks_relevantes:
        # Pode ser útil retornar a mensagem de nenhum contexto encontrado diretamente da função de busca,
        # mas manter aqui também é uma salvaguarda.
        return "Não foram encontrados contextos relevantes nos documentos para responder a esta pergunta."

    contexto_str = "\n\n".join([
        f"Trecho do Arquivo '{chunk.get('arquivo_origem', 'Desconhecido')}', Página {chunk.get('pagina', 'N/A')}:\n\"{chunk.get('texto', '')}\""
        for chunk in chunks_relevantes if chunk.get('texto')
    ])
    
    prompt = f"""Você é um assistente especializado em física. Com base nos seguintes trechos extraídos de documentos, responda à pergunta de forma clara e concisa.
Se a informação não estiver nos trechos fornecidos ou não for suficiente, indique que não pode responder com base no contexto fornecido.

Contextos extraídos:
{contexto_str}

Pergunta do usuário: {pergunta}

Resposta:"""

    print(f"\n--- Prompt enviado para o modelo generativo ({nome_modelo_generativo}) ---")
    # print(prompt) # Descomente para ver o prompt completo no log, pode ser verboso
    print("----------------------------------------------------------")

    try:
        model = genai.GenerativeModel(nome_modelo_generativo) # Usa a variável global MODELO_GEMINI_PARA_GERACAO
        response = model.generate_content(prompt)
        # print(f"Resposta recebida do modelo generativo: {response.text[:200]}...") # Log da resposta, já presente na interface_rag_fisica
        return response.text
    except Exception as e:
        print(f"Erro ao gerar resposta com Gemini ({nome_modelo_generativo}): {e}")
        traceback.print_exc()
        return "Desculpe, ocorreu um erro ao tentar gerar a resposta."

print("Funções auxiliares `buscar_textos_similares` e `gerar_resposta_com_contexto` (ajustadas para múltiplos PDFs) definidas.")
# Out:
# Funções auxiliares `buscar_textos_similares` e `gerar_resposta_com_contexto` (ajustadas para múltiplos PDFs) definidas.

# %%
# CÉLULA 8 - Interface gráfica com gradio
import gradio as gr 

# Variáveis globais que esta função usará (definidas em células anteriores):
# qdrant_client, GOOGLE_AI_API_KEY, COLLECTION_NAME, GEMINI_EMBEDDING_MODEL, MODELO_GEMINI_PARA_GERACAO

def interface_rag_fisica(pergunta_usuario):
    """
    Função principal que o Gradio chamará.
    Orquestra a busca de chunks e a geração da resposta.
    """
    if not qdrant_client or not GOOGLE_AI_API_KEY:
        return "ERRO: Configuração inicial incompleta (Qdrant ou API Google não disponíveis)."
    if not pergunta_usuario or not pergunta_usuario.strip():
        return "Por favor, digite sua pergunta sobre física."

    print(f"\n[Gradio Interface] Pergunta recebida: '{pergunta_usuario}'")

    # 1. Buscar chunks relevantes
    chunks_encontrados = buscar_textos_similares(
        query_text=pergunta_usuario,
        q_client=qdrant_client,
        collection_name=COLLECTION_NAME, # Definida na Célula 3
        gemini_model_embedding=GEMINI_EMBEDDING_MODEL, # Definida na Célula 3
        top_k=3 # Número de chunks para usar como contexto
    )

    if not chunks_encontrados:
        print("[Gradio Interface] Nenhum chunk relevante encontrado.")
        return "Desculpe, não encontrei informações relevantes em seus documentos para responder a essa pergunta."

    print(f"[Gradio Interface] Chunks encontrados para contexto: {len(chunks_encontrados)}")
    for i, chunk in enumerate(chunks_encontrados):
        print(f"  Chunk {i+1} (Página: {chunk.get('pagina','N/A')} Score: {chunk.get('score',0):.4f}): {str(chunk.get('texto',''))[:100]}...")


    # 2. Gerar resposta usando os chunks como contexto
    resposta_final = gerar_resposta_com_contexto(
        pergunta=pergunta_usuario,
        chunks_relevantes=chunks_encontrados,
        nome_modelo_generativo=MODELO_GEMINI_PARA_GERACAO # Definida na célula anterior
    )
    
    print(f"[Gradio Interface] Resposta final gerada.")
    return resposta_final

# Criar a interface Gradio
iface = gr.Interface(
    fn=interface_rag_fisica,
    inputs=gr.Textbox(lines=3, placeholder="Digite aqui ...", label="🤔 Pergunte ao Universo da Física:"),
    outputs=gr.Markdown(label="Resposta do Assistente de Física"), # Usar Markdown para melhor formatação
    title="Assistente RAG de Física com Gemini e Qdrant",
    description="Faça uma pergunta sobre o conteúdo do seu PDF de física. O sistema buscará informações relevantes e gerará uma resposta.",
    allow_flagging="never",
    theme=gr.themes.Base(
        primary_hue=gr.themes.colors.indigo,
        secondary_hue=gr.themes.colors.pink,
        neutral_hue=gr.themes.colors.slate,
        # MUDANÇA PRINCIPAL AQUI:
        font=[gr.themes.GoogleFont("JetBrains Mono"), "ui-monospace", "monospace"], 
        text_size=gr.themes.sizes.text_md
    ),# Desabilita o botão de "flag"
    examples=[
        ["O que é velocidade média?"],
        ["Explique as leis de Newton."],
        ["Qual a diferença entre massa e peso?"]
    ],
    submit_btn="Enviar",
    clear_btn="Limpar"
)

# Lançar a interface
# Se estiver no Google Colab ou quiser um link público, use iface.launch(share=True)
# Para execução local, iface.launch() é geralmente suficiente.
if 'qdrant_client' in locals() and qdrant_client and 'GOOGLE_AI_API_KEY' in locals() and GOOGLE_AI_API_KEY :
    print("Lançando interface Gradio...")
    iface.launch()
else:
    print("ERRO: Não foi possível lançar a interface Gradio devido a configurações ausentes (Qdrant client ou Google API Key).")
# Out:
# C:\Users\rebec\anaconda3\Lib\site-packages\gradio\interface.py:416: UserWarning: The `allow_flagging` parameter in `Interface` is deprecated.Use `flagging_mode` instead.
#   warnings.warn(
# Lançando interface Gradio...
# * Running on local URL:  http://127.0.0.1:7860
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7860/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
